# %%
import numpy as np
import pandas as pd
import torch
import csv
import transformers
import torch.nn as nn
import torch.utils.data as Data
import torch.nn.functional as F
import json
from torch.optim import AdamW
from transformers import AutoTokenizer,AutoModelForSequenceClassification, AutoConfig, get_linear_schedule_with_warmup
import warnings

# %%
warnings.filterwarnings('ignore')
device = 'cuda'
MODEL_NAME = "hfl/chinese-bert-wwm"
#MODEL_NAME = 'bert-base-chinese'
MAX_LEN = 32
EPOCHS = 5
BATCH_SIZE = 32 
LR = 5e-5 
WARMUP_STEP = 100

# %% [markdown]
# 创建load_dataset function

# %%
tokenizer = AutoTokenizer.from_pretrained(MODEL_NAME)

# %%
def load_dataset(filepath, max_len):
    label = []
    sentences = []
    # load dataset
    f = open(filepath, 'r', encoding='utf-8')
    r = csv.reader(f)
    for item in r:
        if r.line_num == 1:
            continue
        label.append(int(item[0]))
        sentences.append(item[1])
        
    input_ids = []
    attention_masks = []

    # For every sentence...
    for data in sentences:
        encoded_data = tokenizer.encode_plus(
            text=data,                      # Preprocess sentence
            add_special_tokens=True,        # Add `[CLS]` and `[SEP]`
            max_length=max_len,             # Max length to truncate/pad
            padding='max_length',           # Pad sentence to max length
            return_attention_mask=True,      # Return attention mask
            truncation= True
            )
        
        # Add the outputs to the lists
        input_ids.append(encoded_data.get('input_ids'))
        attention_masks.append(encoded_data.get('attention_mask'))

    # Convert lists to tensors
    input_ids = torch.tensor(input_ids)
    attention_masks = torch.tensor(attention_masks)
    labels = torch.tensor(label)
    return input_ids, attention_masks, labels

# %%
def batch_accuracy(pre, label):
    pre = pre.argmax(dim=1)
    correct = torch.eq(pre, label).sum().float().item()
    accuracy = correct / float(len(label))

    return accuracy

# %%
import os
path = os.path.abspath(os.path.dirname(os.getcwd()))

# %% [markdown]
# load dataset

# %%
train_dataset = load_dataset(f'{path}/data/db2/train.csv', max_len = MAX_LEN)
valid_dataset = load_dataset(f'{path}/data/db2/dev.csv', max_len = MAX_LEN)
test_dataset = load_dataset(f'{path}/data/db2/test.csv', max_len = MAX_LEN)

# %%
from torch.utils.data import TensorDataset, DataLoader, RandomSampler, SequentialSampler

train_data = TensorDataset(train_dataset[0], train_dataset[1],train_dataset[2])
train_sampler = RandomSampler(train_data)
train_loader = DataLoader(train_data, sampler=train_sampler, batch_size = BATCH_SIZE)

val_data = TensorDataset(valid_dataset[0],valid_dataset[1],valid_dataset[2])
val_sampler = SequentialSampler(val_data)
val_loader = DataLoader(val_data,sampler=val_sampler, batch_size = BATCH_SIZE)

test_data = TensorDataset(test_dataset[0],test_dataset[1],test_dataset[2])

# %%
torch.cuda.is_available()
# Out:
# True

# %%
config = AutoConfig.from_pretrained(MODEL_NAME)
config.num_labels = 3
model = AutoModelForSequenceClassification.from_pretrained(MODEL_NAME, config=config)
model.cuda()
print()
# Out:
# Some weights of the model checkpoint at hfl/chinese-bert-wwm were not used when initializing BertForSequenceClassification: ['cls.seq_relationship.weight', 'cls.seq_relationship.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.bias', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.decoder.weight']
# - This IS expected if you are initializing BertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at hfl/chinese-bert-wwm and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
optimizer = AdamW(model.parameters(), lr=LR)
total_steps =len(train_loader) * EPOCHS
scheduler = get_linear_schedule_with_warmup(optimizer,num_warmup_steps=WARMUP_STEP,num_training_steps=total_steps)

# %%
# import os
# os.environ['CUDA_LAUNCH_BLOCKING'] = "1"

# %%
model.train()
print('开始训练...')

for epoch in range(EPOCHS):
    loss_t, batch_loss, batch_acc, batch_counts = 0, 0, 0, 0
    
    model.train()
    for step,batch in enumerate(train_loader):
        batch_counts +=1
        # Load batch to GPU
        b_input_ids, b_attn_mask, b_labels = tuple(t.to(device) for t in batch)
        outputs = model(b_input_ids, b_attn_mask, labels=b_labels)
        loss, logits = outputs[:2]
        optimizer.zero_grad()
        
        loss_t += loss.item()
        batch_loss += loss.item()
        
        loss.backward()
        optimizer.step()
        scheduler.step()

        torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)
        
        acc = batch_accuracy(logits, b_labels)
        batch_acc += acc
        
        if (step % 20 == 0 and step != 0) or (step == len(train_loader) - 1):
            print(f'epoch:{epoch} | step:{step} | avg_batch_acc:{batch_acc/batch_counts:^.6f} | avg_batch_loss:{batch_loss/batch_counts:^.6f}')
            batch_acc, batch_loss, batch_counts = 0, 0, 0
        
    avg_train_loss = loss_t / len(train_loader)
    
    #evaluate 
    val_acc, val_loss = [],[]
    model.eval()
    for batch in val_loader:
        b_input_ids, b_attn_mask, b_labels = tuple(t.to(device) for t in batch)
        with torch.no_grad():
            outputs = model(b_input_ids, b_attn_mask, labels=b_labels)
        loss, logits = outputs[:2]
        val_loss.append(loss.item())
        acc = batch_accuracy(logits, b_labels)
        val_acc.append(acc)
        
    val_loss = np.mean(val_loss)
    val_accuracy = np.mean(val_acc)
            
    print(f'epoch:{epoch} | avg_train_loss:{avg_train_loss} | val_loss:{val_loss} | val_accuracy:{val_accuracy}')
    
torch.save(model.state_dict(), 'bert_cla_db2.ckpt')
print('保存训练完成的model...')
# Out:
# 开始训练...
# epoch:0 | step:20 | avg_batch_acc:0.403274 | avg_batch_loss:1.096681
# epoch:0 | step:40 | avg_batch_acc:0.650000 | avg_batch_loss:0.811226
# epoch:0 | step:60 | avg_batch_acc:0.732812 | avg_batch_loss:0.665267
# epoch:0 | step:80 | avg_batch_acc:0.826562 | avg_batch_loss:0.484480
# epoch:0 | step:100 | avg_batch_acc:0.840625 | avg_batch_loss:0.429093
# epoch:0 | step:120 | avg_batch_acc:0.851562 | avg_batch_loss:0.408485
# epoch:0 | step:140 | avg_batch_acc:0.851562 | avg_batch_loss:0.374026
# epoch:0 | step:160 | avg_batch_acc:0.856250 | avg_batch_loss:0.381271
# epoch:0 | step:180 | avg_batch_acc:0.853125 | avg_batch_loss:0.413027
# epoch:0 | step:200 | avg_batch_acc:0.878125 | avg_batch_loss:0.369436
# epoch:0 | step:220 | avg_batch_acc:0.862500 | avg_batch_loss:0.392539
# epoch:0 | step:240 | avg_batch_acc:0.848437 | avg_batch_loss:0.375778
# epoch:0 | step:260 | avg_batch_acc:0.884375 | avg_batch_loss:0.319005
# epoch:0 | step:280 | avg_batch_acc:0.851562 | avg_batch_loss:0.345227
# epoch:0 | step:300 | avg_batch_acc:0.890625 | avg_batch_loss:0.326914
# epoch:0 | step:320 | avg_batch_acc:0.848437 | avg_batch_loss:0.384147
# epoch:0 | step:340 | avg_batch_acc:0.848437 | avg_batch_loss:0.383767
# epoch:0 | step:360 | avg_batch_acc:0.865625 | avg_batch_loss:0.361434
# epoch:0 | step:380 | avg_batch_acc:0.845313 | avg_batch_loss:0.402301
# epoch:0 | step:400 | avg_batch_acc:0.864062 | avg_batch_loss:0.354824
# epoch:0 | step:420 | avg_batch_acc:0.853125 | avg_batch_loss:0.367501
# epoch:0 | step:440 | avg_batch_acc:0.857812 | avg_batch_loss:0.371126
# epoch:0 | step:460 | avg_batch_acc:0.851562 | avg_batch_loss:0.379296
# epoch:0 | step:480 | avg_batch_acc:0.887500 | avg_batch_loss:0.313201
# epoch:0 | step:500 | avg_batch_acc:0.871875 | avg_batch_loss:0.337928
# epoch:0 | step:520 | avg_batch_acc:0.868750 | avg_batch_loss:0.375751
# epoch:0 | step:540 | avg_batch_acc:0.864062 | avg_batch_loss:0.339519
# epoch:0 | step:560 | avg_batch_acc:0.865625 | avg_batch_loss:0.337035
# epoch:0 | step:580 | avg_batch_acc:0.893750 | avg_batch_loss:0.280263
# epoch:0 | step:600 | avg_batch_acc:0.864062 | avg_batch_loss:0.328681
# epoch:0 | step:620 | avg_batch_acc:0.882812 | avg_batch_loss:0.302896
# epoch:0 | step:640 | avg_batch_acc:0.864062 | avg_batch_loss:0.342876
# epoch:0 | step:660 | avg_batch_acc:0.873437 | avg_batch_loss:0.333643
# epoch:0 | step:680 | avg_batch_acc:0.842187 | avg_batch_loss:0.414918
# epoch:0 | step:700 | avg_batch_acc:0.890625 | avg_batch_loss:0.304534
# epoch:0 | step:720 | avg_batch_acc:0.881250 | avg_batch_loss:0.326777
# epoch:0 | step:740 | avg_batch_acc:0.885938 | avg_batch_loss:0.302970
# epoch:0 | step:760 | avg_batch_acc:0.901563 | avg_batch_loss:0.317772
# epoch:0 | step:780 | avg_batch_acc:0.859375 | avg_batch_loss:0.296374
# epoch:0 | step:800 | avg_batch_acc:0.896875 | avg_batch_loss:0.284573
# epoch:0 | step:820 | avg_batch_acc:0.892188 | avg_batch_loss:0.281647
# epoch:0 | step:840 | avg_batch_acc:0.875000 | avg_batch_loss:0.292565
# epoch:0 | step:860 | avg_batch_acc:0.873437 | avg_batch_loss:0.345842
# epoch:0 | step:880 | avg_batch_acc:0.895312 | avg_batch_loss:0.284187
# epoch:0 | step:900 | avg_batch_acc:0.895312 | avg_batch_loss:0.296844
# epoch:0 | step:920 | avg_batch_acc:0.867188 | avg_batch_loss:0.326008
# epoch:0 | step:940 | avg_batch_acc:0.889062 | avg_batch_loss:0.296835
# epoch:0 | step:960 | avg_batch_acc:0.870313 | avg_batch_loss:0.340875
# epoch:0 | step:980 | avg_batch_acc:0.887500 | avg_batch_loss:0.291486
# epoch:0 | step:1000 | avg_batch_acc:0.879687 | avg_batch_loss:0.319116
# epoch:0 | step:1020 | avg_batch_acc:0.870313 | avg_batch_loss:0.329458
# epoch:0 | step:1040 | avg_batch_acc:0.871875 | avg_batch_loss:0.338600
# epoch:0 | step:1060 | avg_batch_acc:0.882812 | avg_batch_loss:0.309973
# epoch:0 | step:1080 | avg_batch_acc:0.875000 | avg_batch_loss:0.303786
# epoch:0 | step:1100 | avg_batch_acc:0.879687 | avg_batch_loss:0.306457
# epoch:0 | step:1120 | avg_batch_acc:0.878125 | avg_batch_loss:0.289374
# epoch:0 | step:1140 | avg_batch_acc:0.898438 | avg_batch_loss:0.286953
# epoch:0 | step:1160 | avg_batch_acc:0.868750 | avg_batch_loss:0.337030
# epoch:0 | step:1180 | avg_batch_acc:0.904687 | avg_batch_loss:0.253529
# epoch:0 | step:1200 | avg_batch_acc:0.868750 | avg_batch_loss:0.312334
# epoch:0 | step:1220 | avg_batch_acc:0.873437 | avg_batch_loss:0.318742
# epoch:0 | step:1240 | avg_batch_acc:0.867188 | avg_batch_loss:0.305458
# epoch:0 | step:1260 | avg_batch_acc:0.893750 | avg_batch_loss:0.278641
# epoch:0 | step:1280 | avg_batch_acc:0.870313 | avg_batch_loss:0.338153
# epoch:0 | step:1300 | avg_batch_acc:0.875000 | avg_batch_loss:0.332863
# epoch:0 | step:1320 | avg_batch_acc:0.875000 | avg_batch_loss:0.310226
# epoch:0 | step:1340 | avg_batch_acc:0.864062 | avg_batch_loss:0.311054
# epoch:0 | step:1360 | avg_batch_acc:0.875000 | avg_batch_loss:0.324570
# epoch:0 | step:1380 | avg_batch_acc:0.864062 | avg_batch_loss:0.314154
# epoch:0 | step:1400 | avg_batch_acc:0.868750 | avg_batch_loss:0.290133
# epoch:0 | step:1420 | avg_batch_acc:0.882812 | avg_batch_loss:0.276298
# epoch:0 | step:1440 | avg_batch_acc:0.870313 | avg_batch_loss:0.343224
# epoch:0 | step:1460 | avg_batch_acc:0.884375 | avg_batch_loss:0.284883
# epoch:0 | step:1480 | avg_batch_acc:0.876563 | avg_batch_loss:0.275513
# epoch:0 | step:1500 | avg_batch_acc:0.896875 | avg_batch_loss:0.272420
# epoch:0 | step:1520 | avg_batch_acc:0.879687 | avg_batch_loss:0.309182
# epoch:0 | step:1540 | avg_batch_acc:0.890625 | avg_batch_loss:0.283269
# epoch:0 | step:1560 | avg_batch_acc:0.871875 | avg_batch_loss:0.316788
# epoch:0 | step:1580 | avg_batch_acc:0.890625 | avg_batch_loss:0.269205
# epoch:0 | step:1600 | avg_batch_acc:0.868750 | avg_batch_loss:0.297945
# epoch:0 | step:1620 | avg_batch_acc:0.887500 | avg_batch_loss:0.289796
# epoch:0 | step:1640 | avg_batch_acc:0.884375 | avg_batch_loss:0.292369
# epoch:0 | step:1660 | avg_batch_acc:0.875000 | avg_batch_loss:0.302946
# epoch:0 | step:1680 | avg_batch_acc:0.890625 | avg_batch_loss:0.271049
# epoch:0 | step:1700 | avg_batch_acc:0.887500 | avg_batch_loss:0.298472
# epoch:0 | step:1720 | avg_batch_acc:0.876563 | avg_batch_loss:0.309593
# epoch:0 | step:1740 | avg_batch_acc:0.903125 | avg_batch_loss:0.253046
# epoch:0 | step:1749 | avg_batch_acc:0.906250 | avg_batch_loss:0.287631
# epoch:0 | avg_train_loss:0.34438538762927057 | val_loss:0.2761563031375408 | val_accuracy:0.894625
# epoch:1 | step:20 | avg_batch_acc:0.927083 | avg_batch_loss:0.178843
# epoch:1 | step:40 | avg_batch_acc:0.921875 | avg_batch_loss:0.206191
# epoch:1 | step:60 | avg_batch_acc:0.895312 | avg_batch_loss:0.258306
# epoch:1 | step:80 | avg_batch_acc:0.912500 | avg_batch_loss:0.214911
# epoch:1 | step:100 | avg_batch_acc:0.934375 | avg_batch_loss:0.210159
# epoch:1 | step:120 | avg_batch_acc:0.945312 | avg_batch_loss:0.141576
# epoch:1 | step:140 | avg_batch_acc:0.920312 | avg_batch_loss:0.234842
# epoch:1 | step:160 | avg_batch_acc:0.917188 | avg_batch_loss:0.196506
# epoch:1 | step:180 | avg_batch_acc:0.929688 | avg_batch_loss:0.187949
# epoch:1 | step:200 | avg_batch_acc:0.907813 | avg_batch_loss:0.223804
# epoch:1 | step:220 | avg_batch_acc:0.896875 | avg_batch_loss:0.234850
# epoch:1 | step:240 | avg_batch_acc:0.915625 | avg_batch_loss:0.201597
# epoch:1 | step:260 | avg_batch_acc:0.923438 | avg_batch_loss:0.201357
# epoch:1 | step:280 | avg_batch_acc:0.918750 | avg_batch_loss:0.187006
# epoch:1 | step:300 | avg_batch_acc:0.920312 | avg_batch_loss:0.177263
# epoch:1 | step:320 | avg_batch_acc:0.918750 | avg_batch_loss:0.234475
# epoch:1 | step:340 | avg_batch_acc:0.909375 | avg_batch_loss:0.250405
# epoch:1 | step:360 | avg_batch_acc:0.901563 | avg_batch_loss:0.228329
# epoch:1 | step:380 | avg_batch_acc:0.926562 | avg_batch_loss:0.211880
# epoch:1 | step:400 | avg_batch_acc:0.928125 | avg_batch_loss:0.189520
# epoch:1 | step:420 | avg_batch_acc:0.925000 | avg_batch_loss:0.225272
# epoch:1 | step:440 | avg_batch_acc:0.914062 | avg_batch_loss:0.222088
# epoch:1 | step:460 | avg_batch_acc:0.926562 | avg_batch_loss:0.198302
# epoch:1 | step:480 | avg_batch_acc:0.925000 | avg_batch_loss:0.201639
# epoch:1 | step:500 | avg_batch_acc:0.912500 | avg_batch_loss:0.214557
# epoch:1 | step:520 | avg_batch_acc:0.914062 | avg_batch_loss:0.210207
# epoch:1 | step:540 | avg_batch_acc:0.935937 | avg_batch_loss:0.184197
# epoch:1 | step:560 | avg_batch_acc:0.940625 | avg_batch_loss:0.174066
# epoch:1 | step:580 | avg_batch_acc:0.928125 | avg_batch_loss:0.194718
# epoch:1 | step:600 | avg_batch_acc:0.896875 | avg_batch_loss:0.251241
# epoch:1 | step:620 | avg_batch_acc:0.910937 | avg_batch_loss:0.228359
# epoch:1 | step:640 | avg_batch_acc:0.918750 | avg_batch_loss:0.222051
# epoch:1 | step:660 | avg_batch_acc:0.904687 | avg_batch_loss:0.247037
# epoch:1 | step:680 | avg_batch_acc:0.918750 | avg_batch_loss:0.211095
# epoch:1 | step:700 | avg_batch_acc:0.909375 | avg_batch_loss:0.230518
# epoch:1 | step:720 | avg_batch_acc:0.900000 | avg_batch_loss:0.243701
# epoch:1 | step:740 | avg_batch_acc:0.917188 | avg_batch_loss:0.240881
# epoch:1 | step:760 | avg_batch_acc:0.906250 | avg_batch_loss:0.213122
# epoch:1 | step:780 | avg_batch_acc:0.912500 | avg_batch_loss:0.213847
# epoch:1 | step:800 | avg_batch_acc:0.898438 | avg_batch_loss:0.223126
# epoch:1 | step:820 | avg_batch_acc:0.914062 | avg_batch_loss:0.225148
# epoch:1 | step:840 | avg_batch_acc:0.929688 | avg_batch_loss:0.192231
# epoch:1 | step:860 | avg_batch_acc:0.910937 | avg_batch_loss:0.234629
# epoch:1 | step:880 | avg_batch_acc:0.928125 | avg_batch_loss:0.182383
# epoch:1 | step:900 | avg_batch_acc:0.928125 | avg_batch_loss:0.181773
# epoch:1 | step:920 | avg_batch_acc:0.918750 | avg_batch_loss:0.236701
# epoch:1 | step:940 | avg_batch_acc:0.910937 | avg_batch_loss:0.221051
# epoch:1 | step:960 | avg_batch_acc:0.896875 | avg_batch_loss:0.245683
# epoch:1 | step:980 | avg_batch_acc:0.918750 | avg_batch_loss:0.239645
# epoch:1 | step:1000 | avg_batch_acc:0.917188 | avg_batch_loss:0.213390
# epoch:1 | step:1020 | avg_batch_acc:0.914062 | avg_batch_loss:0.222384
# epoch:1 | step:1040 | avg_batch_acc:0.920312 | avg_batch_loss:0.210209
# epoch:1 | step:1060 | avg_batch_acc:0.903125 | avg_batch_loss:0.217840
# epoch:1 | step:1080 | avg_batch_acc:0.907813 | avg_batch_loss:0.257087
# epoch:1 | step:1100 | avg_batch_acc:0.895312 | avg_batch_loss:0.256428
# epoch:1 | step:1120 | avg_batch_acc:0.923438 | avg_batch_loss:0.202257
# epoch:1 | step:1140 | avg_batch_acc:0.904687 | avg_batch_loss:0.247652
# epoch:1 | step:1160 | avg_batch_acc:0.923438 | avg_batch_loss:0.200136
# epoch:1 | step:1180 | avg_batch_acc:0.910937 | avg_batch_loss:0.248749
# epoch:1 | step:1200 | avg_batch_acc:0.915625 | avg_batch_loss:0.220303
# epoch:1 | step:1220 | avg_batch_acc:0.920312 | avg_batch_loss:0.218883
# epoch:1 | step:1240 | avg_batch_acc:0.901563 | avg_batch_loss:0.264010
# epoch:1 | step:1260 | avg_batch_acc:0.912500 | avg_batch_loss:0.232334
# epoch:1 | step:1280 | avg_batch_acc:0.906250 | avg_batch_loss:0.231604
# epoch:1 | step:1300 | avg_batch_acc:0.900000 | avg_batch_loss:0.254629
# epoch:1 | step:1320 | avg_batch_acc:0.920312 | avg_batch_loss:0.224640
# epoch:1 | step:1340 | avg_batch_acc:0.929688 | avg_batch_loss:0.201840
# epoch:1 | step:1360 | avg_batch_acc:0.935937 | avg_batch_loss:0.168357
# epoch:1 | step:1380 | avg_batch_acc:0.906250 | avg_batch_loss:0.228361
# epoch:1 | step:1400 | avg_batch_acc:0.912500 | avg_batch_loss:0.202888
# epoch:1 | step:1420 | avg_batch_acc:0.929688 | avg_batch_loss:0.163601
# epoch:1 | step:1440 | avg_batch_acc:0.901563 | avg_batch_loss:0.224548
# epoch:1 | step:1460 | avg_batch_acc:0.903125 | avg_batch_loss:0.234589
# epoch:1 | step:1480 | avg_batch_acc:0.917188 | avg_batch_loss:0.224247
# epoch:1 | step:1500 | avg_batch_acc:0.920312 | avg_batch_loss:0.218067
# epoch:1 | step:1520 | avg_batch_acc:0.920312 | avg_batch_loss:0.225057
# epoch:1 | step:1540 | avg_batch_acc:0.921875 | avg_batch_loss:0.180664
# epoch:1 | step:1560 | avg_batch_acc:0.918750 | avg_batch_loss:0.214424
# epoch:1 | step:1580 | avg_batch_acc:0.914062 | avg_batch_loss:0.189377
# epoch:1 | step:1600 | avg_batch_acc:0.910937 | avg_batch_loss:0.235975
# epoch:1 | step:1620 | avg_batch_acc:0.926562 | avg_batch_loss:0.210471
# epoch:1 | step:1640 | avg_batch_acc:0.903125 | avg_batch_loss:0.222793
# epoch:1 | step:1660 | avg_batch_acc:0.918750 | avg_batch_loss:0.206488
# epoch:1 | step:1680 | avg_batch_acc:0.920312 | avg_batch_loss:0.233520
# epoch:1 | step:1700 | avg_batch_acc:0.912500 | avg_batch_loss:0.225402
# epoch:1 | step:1720 | avg_batch_acc:0.917188 | avg_batch_loss:0.217893
# epoch:1 | step:1740 | avg_batch_acc:0.917188 | avg_batch_loss:0.237565
# epoch:1 | step:1749 | avg_batch_acc:0.909722 | avg_batch_loss:0.229338
# epoch:1 | avg_train_loss:0.21691248975907054 | val_loss:0.24946708336472512 | val_accuracy:0.900125
# epoch:2 | step:20 | avg_batch_acc:0.946429 | avg_batch_loss:0.132875
# epoch:2 | step:40 | avg_batch_acc:0.956250 | avg_batch_loss:0.112240
# epoch:2 | step:60 | avg_batch_acc:0.932813 | avg_batch_loss:0.149942
# epoch:2 | step:80 | avg_batch_acc:0.950000 | avg_batch_loss:0.128481
# epoch:2 | step:100 | avg_batch_acc:0.956250 | avg_batch_loss:0.109479
# epoch:2 | step:120 | avg_batch_acc:0.946875 | avg_batch_loss:0.146261
# epoch:2 | step:140 | avg_batch_acc:0.945312 | avg_batch_loss:0.144419
# epoch:2 | step:160 | avg_batch_acc:0.950000 | avg_batch_loss:0.135805
# epoch:2 | step:180 | avg_batch_acc:0.960938 | avg_batch_loss:0.115828
# epoch:2 | step:200 | avg_batch_acc:0.951562 | avg_batch_loss:0.156571
# epoch:2 | step:220 | avg_batch_acc:0.925000 | avg_batch_loss:0.183834
# epoch:2 | step:240 | avg_batch_acc:0.940625 | avg_batch_loss:0.144216
# epoch:2 | step:260 | avg_batch_acc:0.956250 | avg_batch_loss:0.106281
# epoch:2 | step:280 | avg_batch_acc:0.945312 | avg_batch_loss:0.156921
# epoch:2 | step:300 | avg_batch_acc:0.942187 | avg_batch_loss:0.144395
# epoch:2 | step:320 | avg_batch_acc:0.957812 | avg_batch_loss:0.115192
# epoch:2 | step:340 | avg_batch_acc:0.950000 | avg_batch_loss:0.123831
# epoch:2 | step:360 | avg_batch_acc:0.935937 | avg_batch_loss:0.164985
# epoch:2 | step:380 | avg_batch_acc:0.954688 | avg_batch_loss:0.118976
# epoch:2 | step:400 | avg_batch_acc:0.931250 | avg_batch_loss:0.183233
# epoch:2 | step:420 | avg_batch_acc:0.943750 | avg_batch_loss:0.151966
# epoch:2 | step:440 | avg_batch_acc:0.931250 | avg_batch_loss:0.168010
# epoch:2 | step:460 | avg_batch_acc:0.960938 | avg_batch_loss:0.109803
# epoch:2 | step:480 | avg_batch_acc:0.940625 | avg_batch_loss:0.163701
# epoch:2 | step:500 | avg_batch_acc:0.964063 | avg_batch_loss:0.099242
# epoch:2 | step:520 | avg_batch_acc:0.954688 | avg_batch_loss:0.127309
# epoch:2 | step:540 | avg_batch_acc:0.960938 | avg_batch_loss:0.108099
# epoch:2 | step:560 | avg_batch_acc:0.951562 | avg_batch_loss:0.116588
# epoch:2 | step:580 | avg_batch_acc:0.953125 | avg_batch_loss:0.157043
# epoch:2 | step:600 | avg_batch_acc:0.946875 | avg_batch_loss:0.135858
# epoch:2 | step:620 | avg_batch_acc:0.937500 | avg_batch_loss:0.158639
# epoch:2 | step:640 | avg_batch_acc:0.931250 | avg_batch_loss:0.145471
# epoch:2 | step:660 | avg_batch_acc:0.950000 | avg_batch_loss:0.137507
# epoch:2 | step:680 | avg_batch_acc:0.960938 | avg_batch_loss:0.110385
# epoch:2 | step:700 | avg_batch_acc:0.951562 | avg_batch_loss:0.142117
# epoch:2 | step:720 | avg_batch_acc:0.953125 | avg_batch_loss:0.103850
# epoch:2 | step:740 | avg_batch_acc:0.945312 | avg_batch_loss:0.153579
# epoch:2 | step:760 | avg_batch_acc:0.943750 | avg_batch_loss:0.125354
# epoch:2 | step:780 | avg_batch_acc:0.954688 | avg_batch_loss:0.134567
# epoch:2 | step:800 | avg_batch_acc:0.942187 | avg_batch_loss:0.152371
# epoch:2 | step:820 | avg_batch_acc:0.948438 | avg_batch_loss:0.154758
# epoch:2 | step:840 | avg_batch_acc:0.950000 | avg_batch_loss:0.140257
# epoch:2 | step:860 | avg_batch_acc:0.939063 | avg_batch_loss:0.139631
# epoch:2 | step:880 | avg_batch_acc:0.946875 | avg_batch_loss:0.143527
# epoch:2 | step:900 | avg_batch_acc:0.950000 | avg_batch_loss:0.161982
# epoch:2 | step:920 | avg_batch_acc:0.948438 | avg_batch_loss:0.127114
# epoch:2 | step:940 | avg_batch_acc:0.956250 | avg_batch_loss:0.122920
# epoch:2 | step:960 | avg_batch_acc:0.953125 | avg_batch_loss:0.130114
# epoch:2 | step:980 | avg_batch_acc:0.943750 | avg_batch_loss:0.171109
# epoch:2 | step:1000 | avg_batch_acc:0.946875 | avg_batch_loss:0.139963
# epoch:2 | step:1020 | avg_batch_acc:0.935937 | avg_batch_loss:0.143632
# epoch:2 | step:1040 | avg_batch_acc:0.937500 | avg_batch_loss:0.160379
# epoch:2 | step:1060 | avg_batch_acc:0.948438 | avg_batch_loss:0.131743
# epoch:2 | step:1080 | avg_batch_acc:0.943750 | avg_batch_loss:0.148527
# epoch:2 | step:1100 | avg_batch_acc:0.946875 | avg_batch_loss:0.131283
# epoch:2 | step:1120 | avg_batch_acc:0.950000 | avg_batch_loss:0.144639
# epoch:2 | step:1140 | avg_batch_acc:0.953125 | avg_batch_loss:0.138346
# epoch:2 | step:1160 | avg_batch_acc:0.940625 | avg_batch_loss:0.148885
# epoch:2 | step:1180 | avg_batch_acc:0.951562 | avg_batch_loss:0.123064
# epoch:2 | step:1200 | avg_batch_acc:0.942187 | avg_batch_loss:0.142012
# epoch:2 | step:1220 | avg_batch_acc:0.939063 | avg_batch_loss:0.157674
# epoch:2 | step:1240 | avg_batch_acc:0.962500 | avg_batch_loss:0.112360
# epoch:2 | step:1260 | avg_batch_acc:0.951562 | avg_batch_loss:0.151029
# epoch:2 | step:1280 | avg_batch_acc:0.940625 | avg_batch_loss:0.170571
# epoch:2 | step:1300 | avg_batch_acc:0.945312 | avg_batch_loss:0.137168
# epoch:2 | step:1320 | avg_batch_acc:0.940625 | avg_batch_loss:0.157459
# epoch:2 | step:1340 | avg_batch_acc:0.934375 | avg_batch_loss:0.181664
# epoch:2 | step:1360 | avg_batch_acc:0.951562 | avg_batch_loss:0.137568
# epoch:2 | step:1380 | avg_batch_acc:0.968750 | avg_batch_loss:0.108878
# epoch:2 | step:1400 | avg_batch_acc:0.953125 | avg_batch_loss:0.121855
# epoch:2 | step:1420 | avg_batch_acc:0.946875 | avg_batch_loss:0.132607
# epoch:2 | step:1440 | avg_batch_acc:0.945312 | avg_batch_loss:0.134104
# epoch:2 | step:1460 | avg_batch_acc:0.948438 | avg_batch_loss:0.131488
# epoch:2 | step:1480 | avg_batch_acc:0.950000 | avg_batch_loss:0.115746
# epoch:2 | step:1500 | avg_batch_acc:0.959375 | avg_batch_loss:0.098019
# epoch:2 | step:1520 | avg_batch_acc:0.931250 | avg_batch_loss:0.160202
# epoch:2 | step:1540 | avg_batch_acc:0.943750 | avg_batch_loss:0.138024
# epoch:2 | step:1560 | avg_batch_acc:0.939063 | avg_batch_loss:0.155457
# epoch:2 | step:1580 | avg_batch_acc:0.957812 | avg_batch_loss:0.117948
# epoch:2 | step:1600 | avg_batch_acc:0.960938 | avg_batch_loss:0.101822
# epoch:2 | step:1620 | avg_batch_acc:0.948438 | avg_batch_loss:0.130102
# epoch:2 | step:1640 | avg_batch_acc:0.953125 | avg_batch_loss:0.128871
# epoch:2 | step:1660 | avg_batch_acc:0.946875 | avg_batch_loss:0.141212
# epoch:2 | step:1680 | avg_batch_acc:0.937500 | avg_batch_loss:0.153110
# epoch:2 | step:1700 | avg_batch_acc:0.956250 | avg_batch_loss:0.160490
# epoch:2 | step:1720 | avg_batch_acc:0.948438 | avg_batch_loss:0.138202
# epoch:2 | step:1740 | avg_batch_acc:0.942187 | avg_batch_loss:0.142671
# epoch:2 | step:1749 | avg_batch_acc:0.958333 | avg_batch_loss:0.113107
# epoch:2 | avg_train_loss:0.13820511475471514 | val_loss:0.29469310225173834 | val_accuracy:0.90125
# epoch:3 | step:20 | avg_batch_acc:0.976190 | avg_batch_loss:0.062776
# epoch:3 | step:40 | avg_batch_acc:0.976562 | avg_batch_loss:0.073900
# epoch:3 | step:60 | avg_batch_acc:0.968750 | avg_batch_loss:0.080878
# epoch:3 | step:80 | avg_batch_acc:0.975000 | avg_batch_loss:0.071578
# epoch:3 | step:100 | avg_batch_acc:0.982812 | avg_batch_loss:0.058090
# epoch:3 | step:120 | avg_batch_acc:0.967187 | avg_batch_loss:0.070886
# epoch:3 | step:140 | avg_batch_acc:0.973437 | avg_batch_loss:0.070652
# epoch:3 | step:160 | avg_batch_acc:0.979688 | avg_batch_loss:0.047775
# epoch:3 | step:180 | avg_batch_acc:0.975000 | avg_batch_loss:0.066957
# epoch:3 | step:200 | avg_batch_acc:0.964063 | avg_batch_loss:0.089814
# epoch:3 | step:220 | avg_batch_acc:0.970313 | avg_batch_loss:0.081117
# epoch:3 | step:240 | avg_batch_acc:0.965625 | avg_batch_loss:0.075392
# epoch:3 | step:260 | avg_batch_acc:0.981250 | avg_batch_loss:0.057666
# epoch:3 | step:280 | avg_batch_acc:0.965625 | avg_batch_loss:0.085439
# epoch:3 | step:300 | avg_batch_acc:0.971875 | avg_batch_loss:0.086518
# epoch:3 | step:320 | avg_batch_acc:0.981250 | avg_batch_loss:0.054654
# epoch:3 | step:340 | avg_batch_acc:0.968750 | avg_batch_loss:0.077767
# epoch:3 | step:360 | avg_batch_acc:0.975000 | avg_batch_loss:0.082284
# epoch:3 | step:380 | avg_batch_acc:0.968750 | avg_batch_loss:0.083435
# epoch:3 | step:400 | avg_batch_acc:0.978125 | avg_batch_loss:0.070981
# epoch:3 | step:420 | avg_batch_acc:0.976562 | avg_batch_loss:0.056695
# epoch:3 | step:440 | avg_batch_acc:0.979688 | avg_batch_loss:0.056603
# epoch:3 | step:460 | avg_batch_acc:0.970313 | avg_batch_loss:0.078269
# epoch:3 | step:480 | avg_batch_acc:0.973437 | avg_batch_loss:0.065709
# epoch:3 | step:500 | avg_batch_acc:0.959375 | avg_batch_loss:0.096207
# epoch:3 | step:520 | avg_batch_acc:0.971875 | avg_batch_loss:0.085940
# epoch:3 | step:540 | avg_batch_acc:0.973437 | avg_batch_loss:0.074214
# epoch:3 | step:560 | avg_batch_acc:0.975000 | avg_batch_loss:0.059502
# epoch:3 | step:580 | avg_batch_acc:0.978125 | avg_batch_loss:0.059852
# epoch:3 | step:600 | avg_batch_acc:0.971875 | avg_batch_loss:0.081041
# epoch:3 | step:620 | avg_batch_acc:0.973437 | avg_batch_loss:0.062995
# epoch:3 | step:640 | avg_batch_acc:0.984375 | avg_batch_loss:0.056944
# epoch:3 | step:660 | avg_batch_acc:0.973437 | avg_batch_loss:0.076516
# epoch:3 | step:680 | avg_batch_acc:0.973437 | avg_batch_loss:0.070493
# epoch:3 | step:700 | avg_batch_acc:0.970313 | avg_batch_loss:0.062649
# epoch:3 | step:720 | avg_batch_acc:0.976562 | avg_batch_loss:0.071138
# epoch:3 | step:740 | avg_batch_acc:0.968750 | avg_batch_loss:0.073702
# epoch:3 | step:760 | avg_batch_acc:0.981250 | avg_batch_loss:0.062274
# epoch:3 | step:780 | avg_batch_acc:0.971875 | avg_batch_loss:0.078035
# epoch:3 | step:800 | avg_batch_acc:0.968750 | avg_batch_loss:0.082652
# epoch:3 | step:820 | avg_batch_acc:0.965625 | avg_batch_loss:0.082060
# epoch:3 | step:840 | avg_batch_acc:0.967187 | avg_batch_loss:0.089126
# epoch:3 | step:860 | avg_batch_acc:0.978125 | avg_batch_loss:0.067907
# epoch:3 | step:880 | avg_batch_acc:0.953125 | avg_batch_loss:0.109431
# epoch:3 | step:900 | avg_batch_acc:0.975000 | avg_batch_loss:0.062363
# epoch:3 | step:920 | avg_batch_acc:0.976562 | avg_batch_loss:0.060996
# epoch:3 | step:940 | avg_batch_acc:0.975000 | avg_batch_loss:0.065493
# epoch:3 | step:960 | avg_batch_acc:0.959375 | avg_batch_loss:0.096282
# epoch:3 | step:980 | avg_batch_acc:0.987500 | avg_batch_loss:0.047311
# epoch:3 | step:1000 | avg_batch_acc:0.970313 | avg_batch_loss:0.075899
# epoch:3 | step:1020 | avg_batch_acc:0.982812 | avg_batch_loss:0.062030
# epoch:3 | step:1040 | avg_batch_acc:0.971875 | avg_batch_loss:0.066273
# epoch:3 | step:1060 | avg_batch_acc:0.971875 | avg_batch_loss:0.076022
# epoch:3 | step:1080 | avg_batch_acc:0.968750 | avg_batch_loss:0.094739
# epoch:3 | step:1100 | avg_batch_acc:0.967187 | avg_batch_loss:0.093741
# epoch:3 | step:1120 | avg_batch_acc:0.971875 | avg_batch_loss:0.076179
# epoch:3 | step:1140 | avg_batch_acc:0.976562 | avg_batch_loss:0.066069
# epoch:3 | step:1160 | avg_batch_acc:0.982812 | avg_batch_loss:0.059241
# epoch:3 | step:1180 | avg_batch_acc:0.976562 | avg_batch_loss:0.069898
# epoch:3 | step:1200 | avg_batch_acc:0.975000 | avg_batch_loss:0.074699
# epoch:3 | step:1220 | avg_batch_acc:0.978125 | avg_batch_loss:0.057722
# epoch:3 | step:1240 | avg_batch_acc:0.978125 | avg_batch_loss:0.078865
# epoch:3 | step:1260 | avg_batch_acc:0.976562 | avg_batch_loss:0.068234
# epoch:3 | step:1280 | avg_batch_acc:0.982812 | avg_batch_loss:0.046440
# epoch:3 | step:1300 | avg_batch_acc:0.984375 | avg_batch_loss:0.051504
# epoch:3 | step:1320 | avg_batch_acc:0.976562 | avg_batch_loss:0.076383
# epoch:3 | step:1340 | avg_batch_acc:0.971875 | avg_batch_loss:0.077632
# epoch:3 | step:1360 | avg_batch_acc:0.976562 | avg_batch_loss:0.065729
# epoch:3 | step:1380 | avg_batch_acc:0.978125 | avg_batch_loss:0.063867
# epoch:3 | step:1400 | avg_batch_acc:0.971875 | avg_batch_loss:0.099811
# epoch:3 | step:1420 | avg_batch_acc:0.970313 | avg_batch_loss:0.084342
# epoch:3 | step:1440 | avg_batch_acc:0.981250 | avg_batch_loss:0.055647
# epoch:3 | step:1460 | avg_batch_acc:0.962500 | avg_batch_loss:0.091612
# epoch:3 | step:1480 | avg_batch_acc:0.965625 | avg_batch_loss:0.068521
# epoch:3 | step:1500 | avg_batch_acc:0.960938 | avg_batch_loss:0.082019
# epoch:3 | step:1520 | avg_batch_acc:0.973437 | avg_batch_loss:0.067178
# epoch:3 | step:1540 | avg_batch_acc:0.971875 | avg_batch_loss:0.083533
# epoch:3 | step:1560 | avg_batch_acc:0.971875 | avg_batch_loss:0.068799
# epoch:3 | step:1580 | avg_batch_acc:0.975000 | avg_batch_loss:0.074292
# epoch:3 | step:1600 | avg_batch_acc:0.976562 | avg_batch_loss:0.063651
# epoch:3 | step:1620 | avg_batch_acc:0.976562 | avg_batch_loss:0.063352
# epoch:3 | step:1640 | avg_batch_acc:0.967187 | avg_batch_loss:0.092762
# epoch:3 | step:1660 | avg_batch_acc:0.982812 | avg_batch_loss:0.053903
# epoch:3 | step:1680 | avg_batch_acc:0.970313 | avg_batch_loss:0.077640
# epoch:3 | step:1700 | avg_batch_acc:0.965625 | avg_batch_loss:0.100627
# epoch:3 | step:1720 | avg_batch_acc:0.965625 | avg_batch_loss:0.093550
# epoch:3 | step:1740 | avg_batch_acc:0.976562 | avg_batch_loss:0.074085
# epoch:3 | step:1749 | avg_batch_acc:0.968750 | avg_batch_loss:0.052256
# epoch:3 | avg_train_loss:0.07273256418128897 | val_loss:0.3269524961821735 | val_accuracy:0.901375
# epoch:4 | step:20 | avg_batch_acc:0.995536 | avg_batch_loss:0.022893
# epoch:4 | step:40 | avg_batch_acc:0.995313 | avg_batch_loss:0.025268
# epoch:4 | step:60 | avg_batch_acc:0.984375 | avg_batch_loss:0.044072
# epoch:4 | step:80 | avg_batch_acc:0.982812 | avg_batch_loss:0.038243
# epoch:4 | step:100 | avg_batch_acc:0.982812 | avg_batch_loss:0.036657
# epoch:4 | step:120 | avg_batch_acc:0.990625 | avg_batch_loss:0.027620
# epoch:4 | step:140 | avg_batch_acc:0.987500 | avg_batch_loss:0.035078
# epoch:4 | step:160 | avg_batch_acc:0.982812 | avg_batch_loss:0.039720
# epoch:4 | step:180 | avg_batch_acc:0.982812 | avg_batch_loss:0.044372
# epoch:4 | step:200 | avg_batch_acc:0.978125 | avg_batch_loss:0.055010
# epoch:4 | step:220 | avg_batch_acc:0.995313 | avg_batch_loss:0.017946
# epoch:4 | step:240 | avg_batch_acc:0.993750 | avg_batch_loss:0.017770
# epoch:4 | step:260 | avg_batch_acc:0.993750 | avg_batch_loss:0.018671
# epoch:4 | step:280 | avg_batch_acc:0.990625 | avg_batch_loss:0.032306
# epoch:4 | step:300 | avg_batch_acc:0.984375 | avg_batch_loss:0.036497
# epoch:4 | step:320 | avg_batch_acc:0.990625 | avg_batch_loss:0.029032
# epoch:4 | step:340 | avg_batch_acc:0.989062 | avg_batch_loss:0.028565
# epoch:4 | step:360 | avg_batch_acc:0.989062 | avg_batch_loss:0.028983
# epoch:4 | step:380 | avg_batch_acc:0.985938 | avg_batch_loss:0.036879
# epoch:4 | step:400 | avg_batch_acc:0.987500 | avg_batch_loss:0.034715
# epoch:4 | step:420 | avg_batch_acc:0.990625 | avg_batch_loss:0.021344
# epoch:4 | step:440 | avg_batch_acc:0.995313 | avg_batch_loss:0.017882
# epoch:4 | step:460 | avg_batch_acc:0.990625 | avg_batch_loss:0.030435
# epoch:4 | step:480 | avg_batch_acc:0.990625 | avg_batch_loss:0.022603
# epoch:4 | step:500 | avg_batch_acc:0.987500 | avg_batch_loss:0.038864
# epoch:4 | step:520 | avg_batch_acc:0.982812 | avg_batch_loss:0.056747
# epoch:4 | step:540 | avg_batch_acc:0.987500 | avg_batch_loss:0.035655
# epoch:4 | step:560 | avg_batch_acc:0.985938 | avg_batch_loss:0.035645
# epoch:4 | step:580 | avg_batch_acc:0.990625 | avg_batch_loss:0.032349
# epoch:4 | step:600 | avg_batch_acc:0.993750 | avg_batch_loss:0.025404
# epoch:4 | step:620 | avg_batch_acc:0.987500 | avg_batch_loss:0.030339
# epoch:4 | step:640 | avg_batch_acc:0.989062 | avg_batch_loss:0.031967
# epoch:4 | step:660 | avg_batch_acc:0.995313 | avg_batch_loss:0.027501
# epoch:4 | step:680 | avg_batch_acc:0.995313 | avg_batch_loss:0.016238
# epoch:4 | step:700 | avg_batch_acc:0.993750 | avg_batch_loss:0.024903
# epoch:4 | step:720 | avg_batch_acc:0.982812 | avg_batch_loss:0.049239
# epoch:4 | step:740 | avg_batch_acc:0.984375 | avg_batch_loss:0.034903
# epoch:4 | step:760 | avg_batch_acc:0.982812 | avg_batch_loss:0.060484
# epoch:4 | step:780 | avg_batch_acc:0.984375 | avg_batch_loss:0.044229
# epoch:4 | step:800 | avg_batch_acc:0.985938 | avg_batch_loss:0.032341
# epoch:4 | step:820 | avg_batch_acc:0.989062 | avg_batch_loss:0.034038
# epoch:4 | step:840 | avg_batch_acc:0.985938 | avg_batch_loss:0.035815
# epoch:4 | step:860 | avg_batch_acc:0.990625 | avg_batch_loss:0.022788
# epoch:4 | step:880 | avg_batch_acc:0.985938 | avg_batch_loss:0.056030
# epoch:4 | step:900 | avg_batch_acc:0.982812 | avg_batch_loss:0.044416
# epoch:4 | step:920 | avg_batch_acc:0.990625 | avg_batch_loss:0.032979
# epoch:4 | step:940 | avg_batch_acc:0.990625 | avg_batch_loss:0.027660
# epoch:4 | step:960 | avg_batch_acc:0.987500 | avg_batch_loss:0.039907
# epoch:4 | step:980 | avg_batch_acc:0.982812 | avg_batch_loss:0.041142
# epoch:4 | step:1000 | avg_batch_acc:0.985938 | avg_batch_loss:0.027607
# epoch:4 | step:1020 | avg_batch_acc:0.993750 | avg_batch_loss:0.023441
# epoch:4 | step:1040 | avg_batch_acc:0.982812 | avg_batch_loss:0.046339
# epoch:4 | step:1060 | avg_batch_acc:0.992188 | avg_batch_loss:0.023615
# epoch:4 | step:1080 | avg_batch_acc:0.989062 | avg_batch_loss:0.037178
# epoch:4 | step:1100 | avg_batch_acc:0.996875 | avg_batch_loss:0.017316
# epoch:4 | step:1120 | avg_batch_acc:0.984375 | avg_batch_loss:0.059092
# epoch:4 | step:1140 | avg_batch_acc:0.987500 | avg_batch_loss:0.038507
# epoch:4 | step:1160 | avg_batch_acc:0.990625 | avg_batch_loss:0.027564
# epoch:4 | step:1180 | avg_batch_acc:0.981250 | avg_batch_loss:0.038546
# epoch:4 | step:1200 | avg_batch_acc:0.992188 | avg_batch_loss:0.024040
# epoch:4 | step:1220 | avg_batch_acc:0.990625 | avg_batch_loss:0.036056
# epoch:4 | step:1240 | avg_batch_acc:0.992188 | avg_batch_loss:0.020260
# epoch:4 | step:1260 | avg_batch_acc:0.982812 | avg_batch_loss:0.039283
# epoch:4 | step:1280 | avg_batch_acc:0.987500 | avg_batch_loss:0.035728
# epoch:4 | step:1300 | avg_batch_acc:0.989062 | avg_batch_loss:0.035097
# epoch:4 | step:1320 | avg_batch_acc:0.990625 | avg_batch_loss:0.034935
# epoch:4 | step:1340 | avg_batch_acc:0.990625 | avg_batch_loss:0.021448
# epoch:4 | step:1360 | avg_batch_acc:0.992188 | avg_batch_loss:0.023648
# epoch:4 | step:1380 | avg_batch_acc:0.993750 | avg_batch_loss:0.021098
# epoch:4 | step:1400 | avg_batch_acc:0.989062 | avg_batch_loss:0.029565
# epoch:4 | step:1420 | avg_batch_acc:0.992188 | avg_batch_loss:0.022929
# epoch:4 | step:1440 | avg_batch_acc:0.992188 | avg_batch_loss:0.024972
# epoch:4 | step:1460 | avg_batch_acc:0.979688 | avg_batch_loss:0.066372
# epoch:4 | step:1480 | avg_batch_acc:0.993750 | avg_batch_loss:0.020409
# epoch:4 | step:1500 | avg_batch_acc:0.987500 | avg_batch_loss:0.041332
# epoch:4 | step:1520 | avg_batch_acc:0.984375 | avg_batch_loss:0.046117
# epoch:4 | step:1540 | avg_batch_acc:0.990625 | avg_batch_loss:0.045591
# epoch:4 | step:1560 | avg_batch_acc:0.992188 | avg_batch_loss:0.026279
# epoch:4 | step:1580 | avg_batch_acc:0.990625 | avg_batch_loss:0.020546
# epoch:4 | step:1600 | avg_batch_acc:0.985938 | avg_batch_loss:0.033518
# epoch:4 | step:1620 | avg_batch_acc:0.992188 | avg_batch_loss:0.027511
# epoch:4 | step:1640 | avg_batch_acc:0.993750 | avg_batch_loss:0.027386
# epoch:4 | step:1660 | avg_batch_acc:0.987500 | avg_batch_loss:0.025939
# epoch:4 | step:1680 | avg_batch_acc:0.984375 | avg_batch_loss:0.034889
# epoch:4 | step:1700 | avg_batch_acc:0.995313 | avg_batch_loss:0.020249
# epoch:4 | step:1720 | avg_batch_acc:0.995313 | avg_batch_loss:0.014608
# epoch:4 | step:1740 | avg_batch_acc:0.990625 | avg_batch_loss:0.027794
# epoch:4 | step:1749 | avg_batch_acc:0.993056 | avg_batch_loss:0.017991
# epoch:4 | avg_train_loss:0.03257359189947601 | val_loss:0.41658206742885523 | val_accuracy:0.901875
# 保存训练完成的model...

# %%
print('开始加载训练完成的model...')
model.load_state_dict(torch.load('bert_cla_db2.ckpt'))
# Out:
# 开始加载训练完成的model...
# <All keys matched successfully>

# %%
print('开始测试...')
model.eval()
test_result = []
for data in test_data:
    b_input_ids, b_attn_mask, b_labels = tuple(t.to(device) for t in data)
    b_input = b_input_ids.unsqueeze(0)
    
    with torch.no_grad():
        outputs = model(b_input)
        pre = outputs.logits.argmax(dim=1)
        test_result.append([b_labels.item(), pre.item(), tokenizer.convert_ids_to_tokens(b_input_ids)])

# 写入csv文件
df = pd.DataFrame(test_result)
df.to_csv('test_result_db2.csv',index=False, header=['id', 'label','text'])
# Out:
# 开始测试...

# %%
import pandas as pd
df = pd.read_csv('test_result_db2.csv')
df[df.id!=df.label]
# Out:
#        id  label                                               text
# 3       2      0  ['[CLS]', '我', '申', '请', '了', '大', '同', '飞', '...
# 8       0      2  ['[CLS]', '没', '答', '应', '[UNK]', '[SEP]', '[P...
# 12      2      1  ['[CLS]', '那', '你', '就', '不', '要', '出', '事', '...
# 15      1      0  ['[CLS]', '免', '费', '领', '1g', '[SEP]', '[PAD]...
# 24      2      0  ['[CLS]', '我', '没', '有', '这', '么', '多', '的', '...
# ...    ..    ...                                                ...
# 15948   1      0  ['[CLS]', '更', '多', '的', '优', '惠', '[SEP]', '[...
# 15964   2      0  ['[CLS]', '你', '是', '谁', '不', '重', '要', '[SEP]...
# 15966   2      0  ['[CLS]', '操', '你', '可', '以', '吗', '[SEP]', '[...
# 15974   1      0  ['[CLS]', '真', '不', '容', '易', '勇', '敢', '勇', '...
# 15987   1      0  ['[CLS]', 'so', '##ea', '##sy', '##y', '[SEP]'...
#
# [2504 rows x 3 columns]

# %%
df
# Out:
#        id  label                                               text
# 0       1      1  ['[CLS]', '很', '惊', '叹', '不', '用', '谢', '谢', '...
# 1       2      2  ['[CLS]', '你', '好', '我', '购', '票', '失', '败', '...
# 2       0      0  ['[CLS]', '好', '多', '次', '这', '样', '了', '[SEP]...
# 3       2      0  ['[CLS]', '我', '申', '请', '了', '大', '同', '飞', '...
# 4       1      1  ['[CLS]', '这', '个', '有', '效', '的', '吧', '[SEP]...
# ...    ..    ...                                                ...
# 15995   0      0  ['[CLS]', '除', '了', '用', '身', '份', '证', '还', '...
# 15996   1      1  ['[CLS]', '我', '到', '了', '亲', '爱', '的', '第', '...
# 15997   0      0  ['[CLS]', '山', '家', '庭', '宽', '带', '20', '##m'...
# 15998   0      0  ['[CLS]', '送', '票', '最', '起', '码', '应', '该', '...
# 15999   1      1  ['[CLS]', '那', '就', '没', '问', '题', '了', '谢', '...
#
# [16000 rows x 3 columns]

# %%
df[df.id!=df.label][df.label ==0]
# Out:
#        id  label                                               text
# 3       2      0  ['[CLS]', '我', '申', '请', '了', '大', '同', '飞', '...
# 15      1      0  ['[CLS]', '免', '费', '领', '1g', '[SEP]', '[PAD]...
# 24      2      0  ['[CLS]', '我', '没', '有', '这', '么', '多', '的', '...
# 32      2      0  ['[CLS]', '不', '开', '了', '可', '以', '吧', '[SEP]...
# 33      2      0  ['[CLS]', '一', '时', '可', '以', '查', '一', '时', '...
# ...    ..    ...                                                ...
# 15948   1      0  ['[CLS]', '更', '多', '的', '优', '惠', '[SEP]', '[...
# 15964   2      0  ['[CLS]', '你', '是', '谁', '不', '重', '要', '[SEP]...
# 15966   2      0  ['[CLS]', '操', '你', '可', '以', '吗', '[SEP]', '[...
# 15974   1      0  ['[CLS]', '真', '不', '容', '易', '勇', '敢', '勇', '...
# 15987   1      0  ['[CLS]', 'so', '##ea', '##sy', '##y', '[SEP]'...
#
# [1903 rows x 3 columns]

# %%
len(df[df.id==df.label])/len(df)
# Out:
# 0.8435
