# %%
import numpy as np
import pandas as pd
import torch
import csv
import transformers
import torch.nn as nn
import torch.utils.data as Data
import torch.nn.functional as F
import json
from torch.optim import AdamW
from transformers import AutoTokenizer,AutoModelForSequenceClassification, AutoConfig, get_linear_schedule_with_warmup
import warnings

# %%
warnings.filterwarnings('ignore')
device = 'cuda'
MODEL_NAME = "hfl/chinese-bert-wwm"
#MODEL_NAME = 'bert-base-chinese'
MAX_LEN = 32
EPOCHS = 5
BATCH_SIZE = 32 
LR = 5e-5 
WARMUP_STEP = 100

# %% [markdown]
# 创建load_dataset function

# %%
tokenizer = AutoTokenizer.from_pretrained(MODEL_NAME)

# %%
def load_dataset(filepath, max_len):
    label = []
    sentences = []
    # load dataset
    f = open(filepath, 'r', encoding='utf-8')
    r = csv.reader(f)
    for item in r:
        if r.line_num == 1:
            continue
        label.append(int(item[0]))
        sentences.append(item[1])
        
    input_ids = []
    attention_masks = []

    # For every sentence...
    for data in sentences:
        encoded_data = tokenizer.encode_plus(
            text=data,                      # Preprocess sentence
            add_special_tokens=True,        # Add `[CLS]` and `[SEP]`
            max_length=max_len,             # Max length to truncate/pad
            padding='max_length',           # Pad sentence to max length
            return_attention_mask=True,      # Return attention mask
            truncation= True
            )
        
        # Add the outputs to the lists
        input_ids.append(encoded_data.get('input_ids'))
        attention_masks.append(encoded_data.get('attention_mask'))

    # Convert lists to tensors
    input_ids = torch.tensor(input_ids)
    attention_masks = torch.tensor(attention_masks)
    labels = torch.tensor(label)
    return input_ids, attention_masks, labels

# %%
def batch_accuracy(pre, label):
    pre = pre.argmax(dim=1)
    correct = torch.eq(pre, label).sum().float().item()
    accuracy = correct / float(len(label))

    return accuracy

# %%
import os
path = os.path.abspath(os.path.dirname(os.getcwd()))

# %% [markdown]
# load dataset

# %%
train_dataset = load_dataset(f'{path}/data/train.csv', max_len = MAX_LEN)
valid_dataset = load_dataset(f'{path}/data/dev.csv', max_len = MAX_LEN)
test_dataset = load_dataset(f'{path}/data/test.csv', max_len = MAX_LEN)

# %%
from torch.utils.data import TensorDataset, DataLoader, RandomSampler, SequentialSampler

train_data = TensorDataset(train_dataset[0], train_dataset[1],train_dataset[2])
train_sampler = RandomSampler(train_data)
train_loader = DataLoader(train_data, sampler=train_sampler, batch_size = BATCH_SIZE)

val_data = TensorDataset(valid_dataset[0],valid_dataset[1],valid_dataset[2])
val_sampler = SequentialSampler(val_data)
val_loader = DataLoader(val_data,sampler=val_sampler, batch_size = BATCH_SIZE)

test_data = TensorDataset(test_dataset[0],test_dataset[1],test_dataset[2])

# %%
torch.cuda.is_available()
# Out:
# True

# %%
config = AutoConfig.from_pretrained(MODEL_NAME)
config.num_labels = 3
model = AutoModelForSequenceClassification.from_pretrained(MODEL_NAME, config=config)
model.cuda()
print()
# Out:
# Some weights of the model checkpoint at hfl/chinese-bert-wwm were not used when initializing BertForSequenceClassification: ['cls.predictions.transform.dense.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.seq_relationship.weight', 'cls.predictions.decoder.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.seq_relationship.bias', 'cls.predictions.bias']
# - This IS expected if you are initializing BertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at hfl/chinese-bert-wwm and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
optimizer = AdamW(model.parameters(), lr=LR)
total_steps =len(train_loader) * EPOCHS
scheduler = get_linear_schedule_with_warmup(optimizer,num_warmup_steps=WARMUP_STEP,num_training_steps=total_steps)

# %%
# import os
# os.environ['CUDA_LAUNCH_BLOCKING'] = "1"

# %%
model.train()
print('开始训练...')

for epoch in range(EPOCHS):
    loss_t, batch_loss, batch_acc, batch_counts = 0, 0, 0, 0
    
    model.train()
    for step,batch in enumerate(train_loader):
        batch_counts +=1
        # Load batch to GPU
        b_input_ids, b_attn_mask, b_labels = tuple(t.to(device) for t in batch)
        outputs = model(b_input_ids, b_attn_mask, labels=b_labels)
        loss, logits = outputs[:2]
        optimizer.zero_grad()
        
        loss_t += loss.item()
        batch_loss += loss.item()
        
        loss.backward()
        optimizer.step()
        scheduler.step()

        torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)
        
        acc = batch_accuracy(logits, b_labels)
        batch_acc += acc
        
        if (step % 20 == 0 and step != 0) or (step == len(train_loader) - 1):
            print(f'epoch:{epoch} | step:{step} | avg_batch_acc:{batch_acc/batch_counts:^.6f} | avg_batch_loss:{batch_loss/batch_counts:^.6f}')
            batch_acc, batch_loss, batch_counts = 0, 0, 0
        
    avg_train_loss = loss_t / len(train_loader)
    
    #evaluate 
    val_acc, val_loss = [],[]
    model.eval()
    for batch in val_loader:
        b_input_ids, b_attn_mask, b_labels = tuple(t.to(device) for t in batch)
        with torch.no_grad():
            outputs = model(b_input_ids, b_attn_mask, labels=b_labels)
        loss, logits = outputs[:2]
        val_loss.append(loss.item())
        acc = batch_accuracy(logits, b_labels)
        val_acc.append(acc)
        
    val_loss = np.mean(val_loss)
    val_accuracy = np.mean(val_acc)
            
    print(f'epoch:{epoch} | avg_train_loss:{avg_train_loss} | val_loss:{val_loss} | val_accuracy:{val_accuracy}')
    
torch.save(model.state_dict(), 'bert_cla.ckpt')
print('保存训练完成的model...')
# Out:
# 开始训练...
# epoch:0 | step:20 | avg_batch_acc:0.678571 | avg_batch_loss:0.876083
# epoch:0 | step:40 | avg_batch_acc:0.745313 | avg_batch_loss:0.728562
# epoch:0 | step:60 | avg_batch_acc:0.762500 | avg_batch_loss:0.646523
# epoch:0 | step:80 | avg_batch_acc:0.753125 | avg_batch_loss:0.615368
# epoch:0 | step:100 | avg_batch_acc:0.803125 | avg_batch_loss:0.518772
# epoch:0 | step:120 | avg_batch_acc:0.820312 | avg_batch_loss:0.457180
# epoch:0 | step:140 | avg_batch_acc:0.829688 | avg_batch_loss:0.474986
# epoch:0 | step:160 | avg_batch_acc:0.814063 | avg_batch_loss:0.496113
# epoch:0 | step:180 | avg_batch_acc:0.832812 | avg_batch_loss:0.441473
# epoch:0 | step:200 | avg_batch_acc:0.790625 | avg_batch_loss:0.493925
# epoch:0 | step:220 | avg_batch_acc:0.798438 | avg_batch_loss:0.480164
# epoch:0 | step:240 | avg_batch_acc:0.834375 | avg_batch_loss:0.401562
# epoch:0 | step:260 | avg_batch_acc:0.823438 | avg_batch_loss:0.444360
# epoch:0 | step:280 | avg_batch_acc:0.832812 | avg_batch_loss:0.423479
# epoch:0 | step:300 | avg_batch_acc:0.817187 | avg_batch_loss:0.457081
# epoch:0 | step:320 | avg_batch_acc:0.825000 | avg_batch_loss:0.438339
# epoch:0 | step:340 | avg_batch_acc:0.828125 | avg_batch_loss:0.422738
# epoch:0 | step:360 | avg_batch_acc:0.826562 | avg_batch_loss:0.430869
# epoch:0 | step:380 | avg_batch_acc:0.826562 | avg_batch_loss:0.377098
# epoch:0 | step:400 | avg_batch_acc:0.845313 | avg_batch_loss:0.376918
# epoch:0 | step:420 | avg_batch_acc:0.842187 | avg_batch_loss:0.399355
# epoch:0 | step:440 | avg_batch_acc:0.826562 | avg_batch_loss:0.389688
# epoch:0 | step:460 | avg_batch_acc:0.832812 | avg_batch_loss:0.379380
# epoch:0 | step:480 | avg_batch_acc:0.820312 | avg_batch_loss:0.439609
# epoch:0 | step:500 | avg_batch_acc:0.807813 | avg_batch_loss:0.457417
# epoch:0 | step:520 | avg_batch_acc:0.831250 | avg_batch_loss:0.396069
# epoch:0 | step:540 | avg_batch_acc:0.835938 | avg_batch_loss:0.382689
# epoch:0 | step:560 | avg_batch_acc:0.820312 | avg_batch_loss:0.437054
# epoch:0 | step:580 | avg_batch_acc:0.842187 | avg_batch_loss:0.387357
# epoch:0 | step:600 | avg_batch_acc:0.831250 | avg_batch_loss:0.406868
# epoch:0 | step:620 | avg_batch_acc:0.851562 | avg_batch_loss:0.353575
# epoch:0 | step:640 | avg_batch_acc:0.854688 | avg_batch_loss:0.390698
# epoch:0 | step:660 | avg_batch_acc:0.837500 | avg_batch_loss:0.398537
# epoch:0 | step:680 | avg_batch_acc:0.848437 | avg_batch_loss:0.386105
# epoch:0 | step:700 | avg_batch_acc:0.848437 | avg_batch_loss:0.374320
# epoch:0 | step:714 | avg_batch_acc:0.844720 | avg_batch_loss:0.348344
# epoch:0 | avg_train_loss:0.45504792092980206 | val_loss:0.37457961162317144 | val_accuracy:0.850121359223301
# epoch:1 | step:20 | avg_batch_acc:0.858631 | avg_batch_loss:0.326569
# epoch:1 | step:40 | avg_batch_acc:0.884375 | avg_batch_loss:0.260396
# epoch:1 | step:60 | avg_batch_acc:0.864062 | avg_batch_loss:0.321849
# epoch:1 | step:80 | avg_batch_acc:0.848437 | avg_batch_loss:0.326540
# epoch:1 | step:100 | avg_batch_acc:0.907813 | avg_batch_loss:0.228723
# epoch:1 | step:120 | avg_batch_acc:0.871875 | avg_batch_loss:0.269534
# epoch:1 | step:140 | avg_batch_acc:0.867188 | avg_batch_loss:0.327032
# epoch:1 | step:160 | avg_batch_acc:0.868750 | avg_batch_loss:0.318216
# epoch:1 | step:180 | avg_batch_acc:0.878125 | avg_batch_loss:0.311694
# epoch:1 | step:200 | avg_batch_acc:0.879687 | avg_batch_loss:0.300753
# epoch:1 | step:220 | avg_batch_acc:0.878125 | avg_batch_loss:0.308575
# epoch:1 | step:240 | avg_batch_acc:0.867188 | avg_batch_loss:0.311465
# epoch:1 | step:260 | avg_batch_acc:0.864062 | avg_batch_loss:0.352806
# epoch:1 | step:280 | avg_batch_acc:0.870313 | avg_batch_loss:0.294878
# epoch:1 | step:300 | avg_batch_acc:0.879687 | avg_batch_loss:0.284607
# epoch:1 | step:320 | avg_batch_acc:0.882812 | avg_batch_loss:0.273604
# epoch:1 | step:340 | avg_batch_acc:0.846875 | avg_batch_loss:0.368716
# epoch:1 | step:360 | avg_batch_acc:0.860938 | avg_batch_loss:0.312965
# epoch:1 | step:380 | avg_batch_acc:0.871875 | avg_batch_loss:0.290034
# epoch:1 | step:400 | avg_batch_acc:0.882812 | avg_batch_loss:0.274943
# epoch:1 | step:420 | avg_batch_acc:0.871875 | avg_batch_loss:0.320707
# epoch:1 | step:440 | avg_batch_acc:0.879687 | avg_batch_loss:0.281416
# epoch:1 | step:460 | avg_batch_acc:0.875000 | avg_batch_loss:0.283116
# epoch:1 | step:480 | avg_batch_acc:0.842187 | avg_batch_loss:0.364003
# epoch:1 | step:500 | avg_batch_acc:0.889062 | avg_batch_loss:0.291956
# epoch:1 | step:520 | avg_batch_acc:0.887500 | avg_batch_loss:0.278587
# epoch:1 | step:540 | avg_batch_acc:0.873437 | avg_batch_loss:0.305104
# epoch:1 | step:560 | avg_batch_acc:0.862500 | avg_batch_loss:0.322395
# epoch:1 | step:580 | avg_batch_acc:0.854688 | avg_batch_loss:0.330808
# epoch:1 | step:600 | avg_batch_acc:0.875000 | avg_batch_loss:0.314726
# epoch:1 | step:620 | avg_batch_acc:0.875000 | avg_batch_loss:0.310556
# epoch:1 | step:640 | avg_batch_acc:0.870313 | avg_batch_loss:0.326644
# epoch:1 | step:660 | avg_batch_acc:0.887500 | avg_batch_loss:0.275435
# epoch:1 | step:680 | avg_batch_acc:0.864062 | avg_batch_loss:0.347307
# epoch:1 | step:700 | avg_batch_acc:0.864062 | avg_batch_loss:0.314958
# epoch:1 | step:714 | avg_batch_acc:0.847826 | avg_batch_loss:0.341709
# epoch:1 | avg_train_loss:0.30733271080714003 | val_loss:0.38865155466262574 | val_accuracy:0.8467839805825242
# epoch:2 | step:20 | avg_batch_acc:0.931548 | avg_batch_loss:0.184527
# epoch:2 | step:40 | avg_batch_acc:0.923438 | avg_batch_loss:0.211106
# epoch:2 | step:60 | avg_batch_acc:0.915625 | avg_batch_loss:0.203705
# epoch:2 | step:80 | avg_batch_acc:0.912500 | avg_batch_loss:0.230095
# epoch:2 | step:100 | avg_batch_acc:0.926562 | avg_batch_loss:0.185915
# epoch:2 | step:120 | avg_batch_acc:0.915625 | avg_batch_loss:0.211100
# epoch:2 | step:140 | avg_batch_acc:0.910937 | avg_batch_loss:0.183413
# epoch:2 | step:160 | avg_batch_acc:0.903125 | avg_batch_loss:0.237696
# epoch:2 | step:180 | avg_batch_acc:0.915625 | avg_batch_loss:0.222084
# epoch:2 | step:200 | avg_batch_acc:0.914062 | avg_batch_loss:0.229759
# epoch:2 | step:220 | avg_batch_acc:0.912500 | avg_batch_loss:0.224530
# epoch:2 | step:240 | avg_batch_acc:0.910937 | avg_batch_loss:0.231720
# epoch:2 | step:260 | avg_batch_acc:0.937500 | avg_batch_loss:0.169593
# epoch:2 | step:280 | avg_batch_acc:0.912500 | avg_batch_loss:0.198197
# epoch:2 | step:300 | avg_batch_acc:0.920312 | avg_batch_loss:0.193547
# epoch:2 | step:320 | avg_batch_acc:0.909375 | avg_batch_loss:0.212587
# epoch:2 | step:340 | avg_batch_acc:0.900000 | avg_batch_loss:0.197294
# epoch:2 | step:360 | avg_batch_acc:0.920312 | avg_batch_loss:0.206253
# epoch:2 | step:380 | avg_batch_acc:0.917188 | avg_batch_loss:0.196821
# epoch:2 | step:400 | avg_batch_acc:0.917188 | avg_batch_loss:0.205849
# epoch:2 | step:420 | avg_batch_acc:0.906250 | avg_batch_loss:0.245863
# epoch:2 | step:440 | avg_batch_acc:0.889062 | avg_batch_loss:0.255334
# epoch:2 | step:460 | avg_batch_acc:0.925000 | avg_batch_loss:0.220882
# epoch:2 | step:480 | avg_batch_acc:0.896875 | avg_batch_loss:0.240952
# epoch:2 | step:500 | avg_batch_acc:0.926562 | avg_batch_loss:0.196970
# epoch:2 | step:520 | avg_batch_acc:0.915625 | avg_batch_loss:0.206838
# epoch:2 | step:540 | avg_batch_acc:0.921875 | avg_batch_loss:0.196628
# epoch:2 | step:560 | avg_batch_acc:0.914062 | avg_batch_loss:0.200685
# epoch:2 | step:580 | avg_batch_acc:0.912500 | avg_batch_loss:0.232775
# epoch:2 | step:600 | avg_batch_acc:0.928125 | avg_batch_loss:0.196511
# epoch:2 | step:620 | avg_batch_acc:0.898438 | avg_batch_loss:0.242086
# epoch:2 | step:640 | avg_batch_acc:0.909375 | avg_batch_loss:0.222240
# epoch:2 | step:660 | avg_batch_acc:0.925000 | avg_batch_loss:0.189647
# epoch:2 | step:680 | avg_batch_acc:0.920312 | avg_batch_loss:0.198892
# epoch:2 | step:700 | avg_batch_acc:0.925000 | avg_batch_loss:0.202598
# epoch:2 | step:714 | avg_batch_acc:0.925078 | avg_batch_loss:0.203411
# epoch:2 | avg_train_loss:0.21080580858083872 | val_loss:0.4437011289365083 | val_accuracy:0.852245145631068
# epoch:3 | step:20 | avg_batch_acc:0.949405 | avg_batch_loss:0.107590
# epoch:3 | step:40 | avg_batch_acc:0.948438 | avg_batch_loss:0.141828
# epoch:3 | step:60 | avg_batch_acc:0.953125 | avg_batch_loss:0.133778
# epoch:3 | step:80 | avg_batch_acc:0.962500 | avg_batch_loss:0.099922
# epoch:3 | step:100 | avg_batch_acc:0.943750 | avg_batch_loss:0.136893
# epoch:3 | step:120 | avg_batch_acc:0.962500 | avg_batch_loss:0.125661
# epoch:3 | step:140 | avg_batch_acc:0.945312 | avg_batch_loss:0.148769
# epoch:3 | step:160 | avg_batch_acc:0.951562 | avg_batch_loss:0.119992
# epoch:3 | step:180 | avg_batch_acc:0.942187 | avg_batch_loss:0.148787
# epoch:3 | step:200 | avg_batch_acc:0.959375 | avg_batch_loss:0.110944
# epoch:3 | step:220 | avg_batch_acc:0.942187 | avg_batch_loss:0.150554
# epoch:3 | step:240 | avg_batch_acc:0.946875 | avg_batch_loss:0.158488
# epoch:3 | step:260 | avg_batch_acc:0.942187 | avg_batch_loss:0.152268
# epoch:3 | step:280 | avg_batch_acc:0.943750 | avg_batch_loss:0.144435
# epoch:3 | step:300 | avg_batch_acc:0.968750 | avg_batch_loss:0.100108
# epoch:3 | step:320 | avg_batch_acc:0.945312 | avg_batch_loss:0.142549
# epoch:3 | step:340 | avg_batch_acc:0.942187 | avg_batch_loss:0.153073
# epoch:3 | step:360 | avg_batch_acc:0.946875 | avg_batch_loss:0.132100
# epoch:3 | step:380 | avg_batch_acc:0.937500 | avg_batch_loss:0.137517
# epoch:3 | step:400 | avg_batch_acc:0.945312 | avg_batch_loss:0.127335
# epoch:3 | step:420 | avg_batch_acc:0.953125 | avg_batch_loss:0.114250
# epoch:3 | step:440 | avg_batch_acc:0.968750 | avg_batch_loss:0.102181
# epoch:3 | step:460 | avg_batch_acc:0.950000 | avg_batch_loss:0.129604
# epoch:3 | step:480 | avg_batch_acc:0.964063 | avg_batch_loss:0.091874
# epoch:3 | step:500 | avg_batch_acc:0.950000 | avg_batch_loss:0.110423
# epoch:3 | step:520 | avg_batch_acc:0.956250 | avg_batch_loss:0.113451
# epoch:3 | step:540 | avg_batch_acc:0.954688 | avg_batch_loss:0.118684
# epoch:3 | step:560 | avg_batch_acc:0.965625 | avg_batch_loss:0.091543
# epoch:3 | step:580 | avg_batch_acc:0.954688 | avg_batch_loss:0.111568
# epoch:3 | step:600 | avg_batch_acc:0.960938 | avg_batch_loss:0.096818
# epoch:3 | step:620 | avg_batch_acc:0.967187 | avg_batch_loss:0.103296
# epoch:3 | step:640 | avg_batch_acc:0.942187 | avg_batch_loss:0.174418
# epoch:3 | step:660 | avg_batch_acc:0.940625 | avg_batch_loss:0.146572
# epoch:3 | step:680 | avg_batch_acc:0.951562 | avg_batch_loss:0.128863
# epoch:3 | step:700 | avg_batch_acc:0.956250 | avg_batch_loss:0.114683
# epoch:3 | step:714 | avg_batch_acc:0.950893 | avg_batch_loss:0.114424
# epoch:3 | avg_train_loss:0.12605023027195797 | val_loss:0.5434684492647648 | val_accuracy:0.8525485436893204
# epoch:4 | step:20 | avg_batch_acc:0.965774 | avg_batch_loss:0.090515
# epoch:4 | step:40 | avg_batch_acc:0.985938 | avg_batch_loss:0.047882
# epoch:4 | step:60 | avg_batch_acc:0.970313 | avg_batch_loss:0.086668
# epoch:4 | step:80 | avg_batch_acc:0.970313 | avg_batch_loss:0.085458
# epoch:4 | step:100 | avg_batch_acc:0.987500 | avg_batch_loss:0.049883
# epoch:4 | step:120 | avg_batch_acc:0.967187 | avg_batch_loss:0.089513
# epoch:4 | step:140 | avg_batch_acc:0.982812 | avg_batch_loss:0.039251
# epoch:4 | step:160 | avg_batch_acc:0.971875 | avg_batch_loss:0.080317
# epoch:4 | step:180 | avg_batch_acc:0.985938 | avg_batch_loss:0.054779
# epoch:4 | step:200 | avg_batch_acc:0.965625 | avg_batch_loss:0.080643
# epoch:4 | step:220 | avg_batch_acc:0.975000 | avg_batch_loss:0.062352
# epoch:4 | step:240 | avg_batch_acc:0.962500 | avg_batch_loss:0.086341
# epoch:4 | step:260 | avg_batch_acc:0.976562 | avg_batch_loss:0.060734
# epoch:4 | step:280 | avg_batch_acc:0.981250 | avg_batch_loss:0.054180
# epoch:4 | step:300 | avg_batch_acc:0.989062 | avg_batch_loss:0.033807
# epoch:4 | step:320 | avg_batch_acc:0.975000 | avg_batch_loss:0.080227
# epoch:4 | step:340 | avg_batch_acc:0.975000 | avg_batch_loss:0.065782
# epoch:4 | step:360 | avg_batch_acc:0.987500 | avg_batch_loss:0.053101
# epoch:4 | step:380 | avg_batch_acc:0.976562 | avg_batch_loss:0.061581
# epoch:4 | step:400 | avg_batch_acc:0.984375 | avg_batch_loss:0.046969
# epoch:4 | step:420 | avg_batch_acc:0.971875 | avg_batch_loss:0.083023
# epoch:4 | step:440 | avg_batch_acc:0.979688 | avg_batch_loss:0.050979
# epoch:4 | step:460 | avg_batch_acc:0.982812 | avg_batch_loss:0.052370
# epoch:4 | step:480 | avg_batch_acc:0.975000 | avg_batch_loss:0.066368
# epoch:4 | step:500 | avg_batch_acc:0.975000 | avg_batch_loss:0.093543
# epoch:4 | step:520 | avg_batch_acc:0.985938 | avg_batch_loss:0.056147
# epoch:4 | step:540 | avg_batch_acc:0.965625 | avg_batch_loss:0.075018
# epoch:4 | step:560 | avg_batch_acc:0.979688 | avg_batch_loss:0.057661
# epoch:4 | step:580 | avg_batch_acc:0.981250 | avg_batch_loss:0.053656
# epoch:4 | step:600 | avg_batch_acc:0.976562 | avg_batch_loss:0.055281
# epoch:4 | step:620 | avg_batch_acc:0.984375 | avg_batch_loss:0.050234
# epoch:4 | step:640 | avg_batch_acc:0.982812 | avg_batch_loss:0.046850
# epoch:4 | step:660 | avg_batch_acc:0.978125 | avg_batch_loss:0.059204
# epoch:4 | step:680 | avg_batch_acc:0.973437 | avg_batch_loss:0.068178
# epoch:4 | step:700 | avg_batch_acc:0.979688 | avg_batch_loss:0.063386
# epoch:4 | step:714 | avg_batch_acc:0.984375 | avg_batch_loss:0.054780
# epoch:4 | avg_train_loss:0.06390921648549423 | val_loss:0.6514686396689091 | val_accuracy:0.8483009708737864
# 保存训练完成的model...

# %%
print('开始加载训练完成的model...')
model.load_state_dict(torch.load('bert_cla.ckpt'))
# Out:
# 开始加载训练完成的model...
# <All keys matched successfully>

# %%
print('开始测试...')
model.eval()
test_result = []
for data in test_data:
    b_input_ids, b_attn_mask, b_labels = tuple(t.to(device) for t in data)
    b_input = b_input_ids.unsqueeze(0)
    
    with torch.no_grad():
        outputs = model(b_input)
        pre = outputs.logits.argmax(dim=1)
        test_result.append([b_labels.item(), pre.item(), tokenizer.convert_ids_to_tokens(b_input_ids)])

# 写入csv文件
df = pd.DataFrame(test_result)
df.to_csv('test_result.csv',index=False, header=['id', 'label','text'])
# Out:
# 开始测试...

# %%
import pandas as pd
df = pd.read_csv('test_result.csv')
df[df.id!=df.label]
# Out:
#       id  label                                               text
# 3      2      0  ['[CLS]', '屁', '民', '也', '是', '民', '[SEP]', '[...
# 4      1      0  ['[CLS]', '加', '油', '吧', '[SEP]', '[PAD]', '[P...
# 14     2      0  ['[CLS]', '太', '扎', '眼', '了', '[SEP]', '[PAD]'...
# 16     1      0  ['[CLS]', '领', '先', '[SEP]', '[PAD]', '[PAD]',...
# 23     2      0  ['[CLS]', '打', '屎', '棍', '[SEP]', '[PAD]', '[P...
# ...   ..    ...                                                ...
# 6523   2      0  ['[CLS]', '成', '渣', '了', '[SEP]', '[PAD]', '[P...
# 6524   1      0  ['[CLS]', '应', '该', '叫', '先', '知', '[SEP]', '[...
# 6525   2      0  ['[CLS]', '3', '输', '了', '。', '[SEP]', '[PAD]'...
# 6526   2      0  ['[CLS]', '就', '是', '太', '贵', '[SEP]', '[PAD]'...
# 6529   1      2  ['[CLS]', '数', '据', '太', 'nb', '了', '[SEP]', '...
#
# [1195 rows x 3 columns]

# %%
df
# Out:
#       id  label                                               text
# 0      0      0  ['[CLS]', '没', '玩', '过', '啊', '[SEP]', '[PAD]'...
# 1      0      0  ['[CLS]', '停', '车', '减', '速', '[SEP]', '[PAD]'...
# 2      0      0  ['[CLS]', '看', '不', '出', '来', '？', '[SEP]', '[...
# 3      2      0  ['[CLS]', '屁', '民', '也', '是', '民', '[SEP]', '[...
# 4      1      0  ['[CLS]', '加', '油', '吧', '[SEP]', '[PAD]', '[P...
# ...   ..    ...                                                ...
# 6530   0      0  ['[CLS]', '专', '赢', '阿', '森', '纳', '[SEP]', '[...
# 6531   0      0  ['[CLS]', '你', '先', '说', '吧', '[SEP]', '[PAD]'...
# 6532   0      0  ['[CLS]', '老', '哥', '吻', '乳', '沟', '[SEP]', '[...
# 6533   0      0  ['[CLS]', '汽', '车', '吧', '[SEP]', '[PAD]', '[P...
# 6534   0      0  ['[CLS]', '叫', '什', '么', '游', '戏', '[SEP]', '[...
#
# [6535 rows x 3 columns]

# %%
df[df.id!=df.label][df.label ==0]
# Out:
#       id  label                                               text
# 3      2      0  ['[CLS]', '屁', '民', '也', '是', '民', '[SEP]', '[...
# 4      1      0  ['[CLS]', '加', '油', '吧', '[SEP]', '[PAD]', '[P...
# 14     2      0  ['[CLS]', '太', '扎', '眼', '了', '[SEP]', '[PAD]'...
# 16     1      0  ['[CLS]', '领', '先', '[SEP]', '[PAD]', '[PAD]',...
# 23     2      0  ['[CLS]', '打', '屎', '棍', '[SEP]', '[PAD]', '[P...
# ...   ..    ...                                                ...
# 6521   2      0  ['[CLS]', '行', '情', '不', '好', '[SEP]', '[PAD]'...
# 6523   2      0  ['[CLS]', '成', '渣', '了', '[SEP]', '[PAD]', '[P...
# 6524   1      0  ['[CLS]', '应', '该', '叫', '先', '知', '[SEP]', '[...
# 6525   2      0  ['[CLS]', '3', '输', '了', '。', '[SEP]', '[PAD]'...
# 6526   2      0  ['[CLS]', '就', '是', '太', '贵', '[SEP]', '[PAD]'...
#
# [1096 rows x 3 columns]

# %%
len(df[df.id==df.label])/len(df)
# Out:
# 0.8171384850803366
