# %%
import numpy as np
import pandas as pd
import torch
import csv
import transformers
import torch.nn as nn
import torch.utils.data as Data
import torch.nn.functional as F
import json
from torch.optim import AdamW
from transformers import AutoTokenizer,AutoModelForSequenceClassification, AutoConfig, get_linear_schedule_with_warmup
import warnings

# %%
warnings.filterwarnings('ignore')
device = 'cuda'
MODEL_NAME = "hfl/chinese-roberta-wwm-ext"
MAX_LEN = 32
EPOCHS = 5
BATCH_SIZE = 32 
LR = 1e-5 
WARMUP_STEP = 100

# %% [markdown]
# 创建load_dataset function

# %%
tokenizer = AutoTokenizer.from_pretrained(MODEL_NAME)

# %%
def load_dataset(filepath, max_len):
    label = []
    sentences = []
    # load dataset
    f = open(filepath, 'r', encoding='utf-8')
    r = csv.reader(f)
    for item in r:
        if r.line_num == 1:
            continue
        label.append(int(item[0]))
        sentences.append(item[1])
        
    input_ids = []
    attention_masks = []

    # For every sentence...
    for data in sentences:
        encoded_data = tokenizer.encode_plus(
            text=data,                      # Preprocess sentence
            add_special_tokens=True,        # Add `[CLS]` and `[SEP]`
            max_length=max_len,             # Max length to truncate/pad
            padding='max_length',           # Pad sentence to max length
            return_attention_mask=True,      # Return attention mask
            truncation= True
            )
        
        # Add the outputs to the lists
        input_ids.append(encoded_data.get('input_ids'))
        attention_masks.append(encoded_data.get('attention_mask'))

    # Convert lists to tensors
    input_ids = torch.tensor(input_ids)
    attention_masks = torch.tensor(attention_masks)
    labels = torch.tensor(label)
    return input_ids, attention_masks, labels

# %%
def batch_accuracy(pre, label):
    pre = pre.argmax(dim=1)
    correct = torch.eq(pre, label).sum().float().item()
    accuracy = correct / float(len(label))

    return accuracy

# %%
import os
path = os.path.abspath(os.path.dirname(os.getcwd()))

# %% [markdown]
# load dataset

# %%
train_dataset = load_dataset(f'{path}/data/db2/train.csv', max_len = MAX_LEN)
valid_dataset = load_dataset(f'{path}/data/db2/dev.csv', max_len = MAX_LEN)
test_dataset = load_dataset(f'{path}/data/db2/test.csv', max_len = MAX_LEN)

# %%
from torch.utils.data import TensorDataset, DataLoader, RandomSampler, SequentialSampler

train_data = TensorDataset(train_dataset[0], train_dataset[1],train_dataset[2])
train_sampler = RandomSampler(train_data)
train_loader = DataLoader(train_data, sampler=train_sampler, batch_size = BATCH_SIZE)

val_data = TensorDataset(valid_dataset[0],valid_dataset[1],valid_dataset[2])
val_sampler = SequentialSampler(val_data)
val_loader = DataLoader(val_data,sampler=val_sampler, batch_size = BATCH_SIZE)

test_data = TensorDataset(test_dataset[0],test_dataset[1],test_dataset[2])

# %%
torch.cuda.is_available()
# Out:
# True

# %%
config = AutoConfig.from_pretrained(MODEL_NAME)
config.num_labels = 3
model = AutoModelForSequenceClassification.from_pretrained(MODEL_NAME, config=config)
model.cuda()
print()
# Out:
# Some weights of the model checkpoint at hfl/chinese-roberta-wwm-ext were not used when initializing BertForSequenceClassification: ['cls.predictions.decoder.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.bias', 'cls.seq_relationship.bias', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.dense.weight', 'cls.seq_relationship.weight']
# - This IS expected if you are initializing BertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at hfl/chinese-roberta-wwm-ext and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
optimizer = AdamW(model.parameters(), lr=LR)
total_steps = len(train_loader) * EPOCHS
scheduler = get_linear_schedule_with_warmup(optimizer,num_warmup_steps=WARMUP_STEP,num_training_steps=total_steps)

# %%
# import os
# os.environ['CUDA_LAUNCH_BLOCKING'] = "1"

# %%
model.train()
print('开始训练...')

for epoch in range(EPOCHS):
    loss_t, batch_loss, batch_acc, batch_counts = 0, 0, 0, 0
    
    model.train()
    for step,batch in enumerate(train_loader):
        batch_counts +=1
        # Load batch to GPU
        b_input_ids, b_attn_mask, b_labels = tuple(t.to(device) for t in batch)
        outputs = model(b_input_ids, b_attn_mask, labels=b_labels)
        loss, logits = outputs[:2]
        optimizer.zero_grad()
        
        loss_t += loss.item()
        batch_loss += loss.item()
        
        loss.backward()
        optimizer.step()
        scheduler.step()

        torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)
        
        acc = batch_accuracy(logits, b_labels)
        batch_acc += acc
        
        if (step % 20 == 0 and step != 0) or (step == len(train_loader) - 1):
            print(f'epoch:{epoch} | step:{step} | avg_batch_acc:{batch_acc/batch_counts:^.6f} | avg_batch_loss:{batch_loss/batch_counts:^.6f}')
            batch_acc, batch_loss, batch_counts = 0, 0, 0
        
    avg_train_loss = loss_t / len(train_loader)
    
    #evaluate 
    val_acc, val_loss = [],[]
    model.eval()
    for batch in val_loader:
        b_input_ids, b_attn_mask, b_labels = tuple(t.to(device) for t in batch)
        with torch.no_grad():
            outputs = model(b_input_ids, b_attn_mask, labels=b_labels)
        loss, logits = outputs[:2]
        val_loss.append(loss.item())
        acc = batch_accuracy(logits, b_labels)
        val_acc.append(acc)
        
    val_loss = np.mean(val_loss)
    val_accuracy = np.mean(val_acc)
            
    print(f'epoch:{epoch} | avg_train_loss:{avg_train_loss} | val_loss:{val_loss} | val_accuracy:{val_accuracy}')
    
torch.save(model.state_dict(), 'bert_cla_db2.ckpt')
print('保存训练完成的model...')
# Out:
# 开始训练...
# epoch:0 | step:20 | avg_batch_acc:0.340774 | avg_batch_loss:1.109239
# epoch:0 | step:40 | avg_batch_acc:0.492188 | avg_batch_loss:1.031364
# epoch:0 | step:60 | avg_batch_acc:0.548438 | avg_batch_loss:0.932588
# epoch:0 | step:80 | avg_batch_acc:0.642188 | avg_batch_loss:0.807720
# epoch:0 | step:100 | avg_batch_acc:0.773438 | avg_batch_loss:0.606215
# epoch:0 | step:120 | avg_batch_acc:0.832812 | avg_batch_loss:0.471189
# epoch:0 | step:140 | avg_batch_acc:0.812500 | avg_batch_loss:0.483473
# epoch:0 | step:160 | avg_batch_acc:0.840625 | avg_batch_loss:0.427754
# epoch:0 | step:180 | avg_batch_acc:0.859375 | avg_batch_loss:0.381533
# epoch:0 | step:200 | avg_batch_acc:0.846875 | avg_batch_loss:0.404822
# epoch:0 | step:220 | avg_batch_acc:0.870313 | avg_batch_loss:0.366435
# epoch:0 | step:240 | avg_batch_acc:0.892188 | avg_batch_loss:0.318301
# epoch:0 | step:260 | avg_batch_acc:0.876563 | avg_batch_loss:0.356952
# epoch:0 | step:280 | avg_batch_acc:0.882812 | avg_batch_loss:0.324294
# epoch:0 | step:300 | avg_batch_acc:0.889062 | avg_batch_loss:0.314569
# epoch:0 | step:320 | avg_batch_acc:0.871875 | avg_batch_loss:0.313549
# epoch:0 | step:340 | avg_batch_acc:0.887500 | avg_batch_loss:0.294756
# epoch:0 | step:360 | avg_batch_acc:0.881250 | avg_batch_loss:0.302949
# epoch:0 | step:380 | avg_batch_acc:0.887500 | avg_batch_loss:0.305687
# epoch:0 | step:400 | avg_batch_acc:0.878125 | avg_batch_loss:0.298599
# epoch:0 | step:420 | avg_batch_acc:0.871875 | avg_batch_loss:0.321671
# epoch:0 | step:440 | avg_batch_acc:0.903125 | avg_batch_loss:0.273738
# epoch:0 | step:460 | avg_batch_acc:0.896875 | avg_batch_loss:0.251937
# epoch:0 | step:480 | avg_batch_acc:0.884375 | avg_batch_loss:0.307968
# epoch:0 | step:500 | avg_batch_acc:0.875000 | avg_batch_loss:0.326899
# epoch:0 | step:520 | avg_batch_acc:0.871875 | avg_batch_loss:0.331816
# epoch:0 | step:540 | avg_batch_acc:0.876563 | avg_batch_loss:0.307082
# epoch:0 | step:560 | avg_batch_acc:0.887500 | avg_batch_loss:0.279358
# epoch:0 | step:580 | avg_batch_acc:0.887500 | avg_batch_loss:0.310947
# epoch:0 | step:600 | avg_batch_acc:0.885938 | avg_batch_loss:0.276585
# epoch:0 | step:620 | avg_batch_acc:0.914062 | avg_batch_loss:0.241159
# epoch:0 | step:640 | avg_batch_acc:0.881250 | avg_batch_loss:0.309880
# epoch:0 | step:660 | avg_batch_acc:0.907813 | avg_batch_loss:0.258746
# epoch:0 | step:680 | avg_batch_acc:0.885938 | avg_batch_loss:0.273603
# epoch:0 | step:700 | avg_batch_acc:0.889062 | avg_batch_loss:0.312943
# epoch:0 | step:720 | avg_batch_acc:0.904687 | avg_batch_loss:0.274515
# epoch:0 | step:740 | avg_batch_acc:0.881250 | avg_batch_loss:0.288351
# epoch:0 | step:760 | avg_batch_acc:0.889062 | avg_batch_loss:0.268782
# epoch:0 | step:780 | avg_batch_acc:0.889062 | avg_batch_loss:0.288286
# epoch:0 | step:800 | avg_batch_acc:0.903125 | avg_batch_loss:0.251604
# epoch:0 | step:820 | avg_batch_acc:0.875000 | avg_batch_loss:0.291914
# epoch:0 | step:840 | avg_batch_acc:0.879687 | avg_batch_loss:0.308797
# epoch:0 | step:860 | avg_batch_acc:0.904687 | avg_batch_loss:0.259283
# epoch:0 | step:880 | avg_batch_acc:0.893750 | avg_batch_loss:0.252866
# epoch:0 | step:900 | avg_batch_acc:0.895312 | avg_batch_loss:0.266106
# epoch:0 | step:920 | avg_batch_acc:0.904687 | avg_batch_loss:0.249522
# epoch:0 | step:940 | avg_batch_acc:0.867188 | avg_batch_loss:0.322600
# epoch:0 | step:960 | avg_batch_acc:0.885938 | avg_batch_loss:0.296649
# epoch:0 | step:980 | avg_batch_acc:0.910937 | avg_batch_loss:0.250784
# epoch:0 | step:1000 | avg_batch_acc:0.882812 | avg_batch_loss:0.308839
# epoch:0 | step:1020 | avg_batch_acc:0.915625 | avg_batch_loss:0.213991
# epoch:0 | step:1040 | avg_batch_acc:0.884375 | avg_batch_loss:0.297306
# epoch:0 | step:1060 | avg_batch_acc:0.881250 | avg_batch_loss:0.307893
# epoch:0 | step:1080 | avg_batch_acc:0.873437 | avg_batch_loss:0.298889
# epoch:0 | step:1100 | avg_batch_acc:0.892188 | avg_batch_loss:0.270291
# epoch:0 | step:1120 | avg_batch_acc:0.885938 | avg_batch_loss:0.280121
# epoch:0 | step:1140 | avg_batch_acc:0.893750 | avg_batch_loss:0.270485
# epoch:0 | step:1160 | avg_batch_acc:0.885938 | avg_batch_loss:0.275742
# epoch:0 | step:1180 | avg_batch_acc:0.917188 | avg_batch_loss:0.226903
# epoch:0 | step:1200 | avg_batch_acc:0.890625 | avg_batch_loss:0.277352
# epoch:0 | step:1220 | avg_batch_acc:0.901563 | avg_batch_loss:0.262571
# epoch:0 | step:1240 | avg_batch_acc:0.898438 | avg_batch_loss:0.253214
# epoch:0 | step:1260 | avg_batch_acc:0.887500 | avg_batch_loss:0.280577
# epoch:0 | step:1280 | avg_batch_acc:0.906250 | avg_batch_loss:0.251918
# epoch:0 | step:1300 | avg_batch_acc:0.882812 | avg_batch_loss:0.271332
# epoch:0 | step:1320 | avg_batch_acc:0.907813 | avg_batch_loss:0.223852
# epoch:0 | step:1340 | avg_batch_acc:0.903125 | avg_batch_loss:0.250947
# epoch:0 | step:1360 | avg_batch_acc:0.901563 | avg_batch_loss:0.231728
# epoch:0 | step:1380 | avg_batch_acc:0.906250 | avg_batch_loss:0.240299
# epoch:0 | step:1400 | avg_batch_acc:0.929688 | avg_batch_loss:0.222510
# epoch:0 | step:1420 | avg_batch_acc:0.912500 | avg_batch_loss:0.223384
# epoch:0 | step:1440 | avg_batch_acc:0.887500 | avg_batch_loss:0.281844
# epoch:0 | step:1460 | avg_batch_acc:0.895312 | avg_batch_loss:0.280761
# epoch:0 | step:1480 | avg_batch_acc:0.887500 | avg_batch_loss:0.258369
# epoch:0 | step:1500 | avg_batch_acc:0.898438 | avg_batch_loss:0.264110
# epoch:0 | step:1520 | avg_batch_acc:0.896875 | avg_batch_loss:0.277504
# epoch:0 | step:1540 | avg_batch_acc:0.892188 | avg_batch_loss:0.258314
# epoch:0 | step:1560 | avg_batch_acc:0.893750 | avg_batch_loss:0.285743
# epoch:0 | step:1580 | avg_batch_acc:0.906250 | avg_batch_loss:0.239833
# epoch:0 | step:1600 | avg_batch_acc:0.906250 | avg_batch_loss:0.222010
# epoch:0 | step:1620 | avg_batch_acc:0.906250 | avg_batch_loss:0.240125
# epoch:0 | step:1640 | avg_batch_acc:0.895312 | avg_batch_loss:0.253633
# epoch:0 | step:1660 | avg_batch_acc:0.884375 | avg_batch_loss:0.278314
# epoch:0 | step:1680 | avg_batch_acc:0.893750 | avg_batch_loss:0.285341
# epoch:0 | step:1700 | avg_batch_acc:0.868750 | avg_batch_loss:0.324593
# epoch:0 | step:1720 | avg_batch_acc:0.875000 | avg_batch_loss:0.308030
# epoch:0 | step:1740 | avg_batch_acc:0.904687 | avg_batch_loss:0.231396
# epoch:0 | step:1749 | avg_batch_acc:0.916667 | avg_batch_loss:0.220093
# epoch:0 | avg_train_loss:0.32332514538509505 | val_loss:0.24222224555909633 | val_accuracy:0.90675
# epoch:1 | step:20 | avg_batch_acc:0.916667 | avg_batch_loss:0.205991
# epoch:1 | step:40 | avg_batch_acc:0.917188 | avg_batch_loss:0.204627
# epoch:1 | step:60 | avg_batch_acc:0.898438 | avg_batch_loss:0.252724
# epoch:1 | step:80 | avg_batch_acc:0.920312 | avg_batch_loss:0.191022
# epoch:1 | step:100 | avg_batch_acc:0.918750 | avg_batch_loss:0.205636
# epoch:1 | step:120 | avg_batch_acc:0.912500 | avg_batch_loss:0.208371
# epoch:1 | step:140 | avg_batch_acc:0.920312 | avg_batch_loss:0.202202
# epoch:1 | step:160 | avg_batch_acc:0.934375 | avg_batch_loss:0.180549
# epoch:1 | step:180 | avg_batch_acc:0.914062 | avg_batch_loss:0.201726
# epoch:1 | step:200 | avg_batch_acc:0.917188 | avg_batch_loss:0.221027
# epoch:1 | step:220 | avg_batch_acc:0.921875 | avg_batch_loss:0.198655
# epoch:1 | step:240 | avg_batch_acc:0.912500 | avg_batch_loss:0.225784
# epoch:1 | step:260 | avg_batch_acc:0.918750 | avg_batch_loss:0.207343
# epoch:1 | step:280 | avg_batch_acc:0.914062 | avg_batch_loss:0.211633
# epoch:1 | step:300 | avg_batch_acc:0.914062 | avg_batch_loss:0.194448
# epoch:1 | step:320 | avg_batch_acc:0.935937 | avg_batch_loss:0.182456
# epoch:1 | step:340 | avg_batch_acc:0.929688 | avg_batch_loss:0.174028
# epoch:1 | step:360 | avg_batch_acc:0.910937 | avg_batch_loss:0.208688
# epoch:1 | step:380 | avg_batch_acc:0.918750 | avg_batch_loss:0.202306
# epoch:1 | step:400 | avg_batch_acc:0.935937 | avg_batch_loss:0.173129
# epoch:1 | step:420 | avg_batch_acc:0.920312 | avg_batch_loss:0.192311
# epoch:1 | step:440 | avg_batch_acc:0.943750 | avg_batch_loss:0.159452
# epoch:1 | step:460 | avg_batch_acc:0.926562 | avg_batch_loss:0.173675
# epoch:1 | step:480 | avg_batch_acc:0.932813 | avg_batch_loss:0.175968
# epoch:1 | step:500 | avg_batch_acc:0.904687 | avg_batch_loss:0.228463
# epoch:1 | step:520 | avg_batch_acc:0.931250 | avg_batch_loss:0.173179
# epoch:1 | step:540 | avg_batch_acc:0.917188 | avg_batch_loss:0.219427
# epoch:1 | step:560 | avg_batch_acc:0.926562 | avg_batch_loss:0.190860
# epoch:1 | step:580 | avg_batch_acc:0.917188 | avg_batch_loss:0.200290
# epoch:1 | step:600 | avg_batch_acc:0.917188 | avg_batch_loss:0.198610
# epoch:1 | step:620 | avg_batch_acc:0.910937 | avg_batch_loss:0.236856
# epoch:1 | step:640 | avg_batch_acc:0.914062 | avg_batch_loss:0.212594
# epoch:1 | step:660 | avg_batch_acc:0.918750 | avg_batch_loss:0.186519
# epoch:1 | step:680 | avg_batch_acc:0.923438 | avg_batch_loss:0.191635
# epoch:1 | step:700 | avg_batch_acc:0.934375 | avg_batch_loss:0.183824
# epoch:1 | step:720 | avg_batch_acc:0.934375 | avg_batch_loss:0.175690
# epoch:1 | step:740 | avg_batch_acc:0.917188 | avg_batch_loss:0.201508
# epoch:1 | step:760 | avg_batch_acc:0.921875 | avg_batch_loss:0.175232
# epoch:1 | step:780 | avg_batch_acc:0.907813 | avg_batch_loss:0.213816
# epoch:1 | step:800 | avg_batch_acc:0.914062 | avg_batch_loss:0.214736
# epoch:1 | step:820 | avg_batch_acc:0.889062 | avg_batch_loss:0.271201
# epoch:1 | step:840 | avg_batch_acc:0.921875 | avg_batch_loss:0.202426
# epoch:1 | step:860 | avg_batch_acc:0.914062 | avg_batch_loss:0.201223
# epoch:1 | step:880 | avg_batch_acc:0.909375 | avg_batch_loss:0.213786
# epoch:1 | step:900 | avg_batch_acc:0.937500 | avg_batch_loss:0.190566
# epoch:1 | step:920 | avg_batch_acc:0.928125 | avg_batch_loss:0.182985
# epoch:1 | step:940 | avg_batch_acc:0.931250 | avg_batch_loss:0.199399
# epoch:1 | step:960 | avg_batch_acc:0.920312 | avg_batch_loss:0.188798
# epoch:1 | step:980 | avg_batch_acc:0.923438 | avg_batch_loss:0.203759
# epoch:1 | step:1000 | avg_batch_acc:0.928125 | avg_batch_loss:0.196295
# epoch:1 | step:1020 | avg_batch_acc:0.925000 | avg_batch_loss:0.183777
# epoch:1 | step:1040 | avg_batch_acc:0.932813 | avg_batch_loss:0.168238
# epoch:1 | step:1060 | avg_batch_acc:0.918750 | avg_batch_loss:0.204638
# epoch:1 | step:1080 | avg_batch_acc:0.928125 | avg_batch_loss:0.201178
# epoch:1 | step:1100 | avg_batch_acc:0.928125 | avg_batch_loss:0.176387
# epoch:1 | step:1120 | avg_batch_acc:0.932813 | avg_batch_loss:0.163813
# epoch:1 | step:1140 | avg_batch_acc:0.932813 | avg_batch_loss:0.200093
# epoch:1 | step:1160 | avg_batch_acc:0.929688 | avg_batch_loss:0.171159
# epoch:1 | step:1180 | avg_batch_acc:0.926562 | avg_batch_loss:0.185523
# epoch:1 | step:1200 | avg_batch_acc:0.917188 | avg_batch_loss:0.226255
# epoch:1 | step:1220 | avg_batch_acc:0.914062 | avg_batch_loss:0.236162
# epoch:1 | step:1240 | avg_batch_acc:0.925000 | avg_batch_loss:0.195892
# epoch:1 | step:1260 | avg_batch_acc:0.906250 | avg_batch_loss:0.230304
# epoch:1 | step:1280 | avg_batch_acc:0.917188 | avg_batch_loss:0.219705
# epoch:1 | step:1300 | avg_batch_acc:0.915625 | avg_batch_loss:0.189492
# epoch:1 | step:1320 | avg_batch_acc:0.934375 | avg_batch_loss:0.182033
# epoch:1 | step:1340 | avg_batch_acc:0.943750 | avg_batch_loss:0.168155
# epoch:1 | step:1360 | avg_batch_acc:0.912500 | avg_batch_loss:0.200529
# epoch:1 | step:1380 | avg_batch_acc:0.929688 | avg_batch_loss:0.180632
# epoch:1 | step:1400 | avg_batch_acc:0.914062 | avg_batch_loss:0.221044
# epoch:1 | step:1420 | avg_batch_acc:0.943750 | avg_batch_loss:0.160142
# epoch:1 | step:1440 | avg_batch_acc:0.907813 | avg_batch_loss:0.228770
# epoch:1 | step:1460 | avg_batch_acc:0.912500 | avg_batch_loss:0.213002
# epoch:1 | step:1480 | avg_batch_acc:0.931250 | avg_batch_loss:0.178723
# epoch:1 | step:1500 | avg_batch_acc:0.915625 | avg_batch_loss:0.205948
# epoch:1 | step:1520 | avg_batch_acc:0.935937 | avg_batch_loss:0.191013
# epoch:1 | step:1540 | avg_batch_acc:0.917188 | avg_batch_loss:0.213586
# epoch:1 | step:1560 | avg_batch_acc:0.900000 | avg_batch_loss:0.256385
# epoch:1 | step:1580 | avg_batch_acc:0.939063 | avg_batch_loss:0.157451
# epoch:1 | step:1600 | avg_batch_acc:0.918750 | avg_batch_loss:0.216091
# epoch:1 | step:1620 | avg_batch_acc:0.928125 | avg_batch_loss:0.171495
# epoch:1 | step:1640 | avg_batch_acc:0.937500 | avg_batch_loss:0.183472
# epoch:1 | step:1660 | avg_batch_acc:0.910937 | avg_batch_loss:0.200490
# epoch:1 | step:1680 | avg_batch_acc:0.909375 | avg_batch_loss:0.184583
# epoch:1 | step:1700 | avg_batch_acc:0.939063 | avg_batch_loss:0.166312
# epoch:1 | step:1720 | avg_batch_acc:0.918750 | avg_batch_loss:0.217823
# epoch:1 | step:1740 | avg_batch_acc:0.921875 | avg_batch_loss:0.189786
# epoch:1 | step:1749 | avg_batch_acc:0.944444 | avg_batch_loss:0.151093
# epoch:1 | avg_train_loss:0.19800917589983769 | val_loss:0.2365667263790965 | val_accuracy:0.9095
# epoch:2 | step:20 | avg_batch_acc:0.946429 | avg_batch_loss:0.133292
# epoch:2 | step:40 | avg_batch_acc:0.940625 | avg_batch_loss:0.149505
# epoch:2 | step:60 | avg_batch_acc:0.935937 | avg_batch_loss:0.140607
# epoch:2 | step:80 | avg_batch_acc:0.945312 | avg_batch_loss:0.152428
# epoch:2 | step:100 | avg_batch_acc:0.940625 | avg_batch_loss:0.158387
# epoch:2 | step:120 | avg_batch_acc:0.950000 | avg_batch_loss:0.138646
# epoch:2 | step:140 | avg_batch_acc:0.931250 | avg_batch_loss:0.163966
# epoch:2 | step:160 | avg_batch_acc:0.929688 | avg_batch_loss:0.171834
# epoch:2 | step:180 | avg_batch_acc:0.948438 | avg_batch_loss:0.147417
# epoch:2 | step:200 | avg_batch_acc:0.937500 | avg_batch_loss:0.148172
# epoch:2 | step:220 | avg_batch_acc:0.923438 | avg_batch_loss:0.183174
# epoch:2 | step:240 | avg_batch_acc:0.954688 | avg_batch_loss:0.119606
# epoch:2 | step:260 | avg_batch_acc:0.946875 | avg_batch_loss:0.152746
# epoch:2 | step:280 | avg_batch_acc:0.928125 | avg_batch_loss:0.174008
# epoch:2 | step:300 | avg_batch_acc:0.939063 | avg_batch_loss:0.161698
# epoch:2 | step:320 | avg_batch_acc:0.945312 | avg_batch_loss:0.144862
# epoch:2 | step:340 | avg_batch_acc:0.932813 | avg_batch_loss:0.151143
# epoch:2 | step:360 | avg_batch_acc:0.948438 | avg_batch_loss:0.148085
# epoch:2 | step:380 | avg_batch_acc:0.962500 | avg_batch_loss:0.124775
# epoch:2 | step:400 | avg_batch_acc:0.940625 | avg_batch_loss:0.158759
# epoch:2 | step:420 | avg_batch_acc:0.943750 | avg_batch_loss:0.153706
# epoch:2 | step:440 | avg_batch_acc:0.950000 | avg_batch_loss:0.132081
# epoch:2 | step:460 | avg_batch_acc:0.957812 | avg_batch_loss:0.125402
# epoch:2 | step:480 | avg_batch_acc:0.951562 | avg_batch_loss:0.128923
# epoch:2 | step:500 | avg_batch_acc:0.954688 | avg_batch_loss:0.131118
# epoch:2 | step:520 | avg_batch_acc:0.939063 | avg_batch_loss:0.148747
# epoch:2 | step:540 | avg_batch_acc:0.946875 | avg_batch_loss:0.148607
# epoch:2 | step:560 | avg_batch_acc:0.945312 | avg_batch_loss:0.134276
# epoch:2 | step:580 | avg_batch_acc:0.954688 | avg_batch_loss:0.135217
# epoch:2 | step:600 | avg_batch_acc:0.937500 | avg_batch_loss:0.155592
# epoch:2 | step:620 | avg_batch_acc:0.945312 | avg_batch_loss:0.146932
# epoch:2 | step:640 | avg_batch_acc:0.939063 | avg_batch_loss:0.162028
# epoch:2 | step:660 | avg_batch_acc:0.940625 | avg_batch_loss:0.150718
# epoch:2 | step:680 | avg_batch_acc:0.931250 | avg_batch_loss:0.163758
# epoch:2 | step:700 | avg_batch_acc:0.946875 | avg_batch_loss:0.149691
# epoch:2 | step:720 | avg_batch_acc:0.937500 | avg_batch_loss:0.168246
# epoch:2 | step:740 | avg_batch_acc:0.940625 | avg_batch_loss:0.169382
# epoch:2 | step:760 | avg_batch_acc:0.950000 | avg_batch_loss:0.147473
# epoch:2 | step:780 | avg_batch_acc:0.935937 | avg_batch_loss:0.162079
# epoch:2 | step:800 | avg_batch_acc:0.950000 | avg_batch_loss:0.111036
# epoch:2 | step:820 | avg_batch_acc:0.939063 | avg_batch_loss:0.169938
# epoch:2 | step:840 | avg_batch_acc:0.945312 | avg_batch_loss:0.143314
# epoch:2 | step:860 | avg_batch_acc:0.943750 | avg_batch_loss:0.139717
# epoch:2 | step:880 | avg_batch_acc:0.951562 | avg_batch_loss:0.125387
# epoch:2 | step:900 | avg_batch_acc:0.954688 | avg_batch_loss:0.121117
# epoch:2 | step:920 | avg_batch_acc:0.942187 | avg_batch_loss:0.158291
# epoch:2 | step:940 | avg_batch_acc:0.925000 | avg_batch_loss:0.172066
# epoch:2 | step:960 | avg_batch_acc:0.934375 | avg_batch_loss:0.165702
# epoch:2 | step:980 | avg_batch_acc:0.959375 | avg_batch_loss:0.121467
# epoch:2 | step:1000 | avg_batch_acc:0.934375 | avg_batch_loss:0.160925
# epoch:2 | step:1020 | avg_batch_acc:0.950000 | avg_batch_loss:0.130108
# epoch:2 | step:1040 | avg_batch_acc:0.959375 | avg_batch_loss:0.127323
# epoch:2 | step:1060 | avg_batch_acc:0.937500 | avg_batch_loss:0.147385
# epoch:2 | step:1080 | avg_batch_acc:0.953125 | avg_batch_loss:0.121518
# epoch:2 | step:1100 | avg_batch_acc:0.942187 | avg_batch_loss:0.127401
# epoch:2 | step:1120 | avg_batch_acc:0.925000 | avg_batch_loss:0.185335
# epoch:2 | step:1140 | avg_batch_acc:0.946875 | avg_batch_loss:0.135824
# epoch:2 | step:1160 | avg_batch_acc:0.946875 | avg_batch_loss:0.141153
# epoch:2 | step:1180 | avg_batch_acc:0.929688 | avg_batch_loss:0.151025
# epoch:2 | step:1200 | avg_batch_acc:0.942187 | avg_batch_loss:0.157145
# epoch:2 | step:1220 | avg_batch_acc:0.959375 | avg_batch_loss:0.116734
# epoch:2 | step:1240 | avg_batch_acc:0.956250 | avg_batch_loss:0.139473
# epoch:2 | step:1260 | avg_batch_acc:0.942187 | avg_batch_loss:0.156460
# epoch:2 | step:1280 | avg_batch_acc:0.935937 | avg_batch_loss:0.143548
# epoch:2 | step:1300 | avg_batch_acc:0.946875 | avg_batch_loss:0.113899
# epoch:2 | step:1320 | avg_batch_acc:0.934375 | avg_batch_loss:0.163606
# epoch:2 | step:1340 | avg_batch_acc:0.935937 | avg_batch_loss:0.147788
# epoch:2 | step:1360 | avg_batch_acc:0.934375 | avg_batch_loss:0.177495
# epoch:2 | step:1380 | avg_batch_acc:0.946875 | avg_batch_loss:0.143883
# epoch:2 | step:1400 | avg_batch_acc:0.951562 | avg_batch_loss:0.148277
# epoch:2 | step:1420 | avg_batch_acc:0.929688 | avg_batch_loss:0.187644
# epoch:2 | step:1440 | avg_batch_acc:0.935937 | avg_batch_loss:0.157218
# epoch:2 | step:1460 | avg_batch_acc:0.948438 | avg_batch_loss:0.137321
# epoch:2 | step:1480 | avg_batch_acc:0.951562 | avg_batch_loss:0.137825
# epoch:2 | step:1500 | avg_batch_acc:0.935937 | avg_batch_loss:0.152491
# epoch:2 | step:1520 | avg_batch_acc:0.957812 | avg_batch_loss:0.132005
# epoch:2 | step:1540 | avg_batch_acc:0.950000 | avg_batch_loss:0.145259
# epoch:2 | step:1560 | avg_batch_acc:0.954688 | avg_batch_loss:0.127798
# epoch:2 | step:1580 | avg_batch_acc:0.946875 | avg_batch_loss:0.132534
# epoch:2 | step:1600 | avg_batch_acc:0.956250 | avg_batch_loss:0.129825
# epoch:2 | step:1620 | avg_batch_acc:0.932813 | avg_batch_loss:0.173995
# epoch:2 | step:1640 | avg_batch_acc:0.962500 | avg_batch_loss:0.104755
# epoch:2 | step:1660 | avg_batch_acc:0.935937 | avg_batch_loss:0.160528
# epoch:2 | step:1680 | avg_batch_acc:0.951562 | avg_batch_loss:0.148678
# epoch:2 | step:1700 | avg_batch_acc:0.934375 | avg_batch_loss:0.160761
# epoch:2 | step:1720 | avg_batch_acc:0.951562 | avg_batch_loss:0.134276
# epoch:2 | step:1740 | avg_batch_acc:0.935937 | avg_batch_loss:0.146259
# epoch:2 | step:1749 | avg_batch_acc:0.944444 | avg_batch_loss:0.146154
# epoch:2 | avg_train_loss:0.14677753738260696 | val_loss:0.24238545363023878 | val_accuracy:0.912375
# epoch:3 | step:20 | avg_batch_acc:0.955357 | avg_batch_loss:0.106874
# epoch:3 | step:40 | avg_batch_acc:0.953125 | avg_batch_loss:0.119387
# epoch:3 | step:60 | avg_batch_acc:0.957812 | avg_batch_loss:0.128259
# epoch:3 | step:80 | avg_batch_acc:0.968750 | avg_batch_loss:0.087366
# epoch:3 | step:100 | avg_batch_acc:0.954688 | avg_batch_loss:0.127461
# epoch:3 | step:120 | avg_batch_acc:0.962500 | avg_batch_loss:0.102605
# epoch:3 | step:140 | avg_batch_acc:0.978125 | avg_batch_loss:0.075382
# epoch:3 | step:160 | avg_batch_acc:0.959375 | avg_batch_loss:0.096583
# epoch:3 | step:180 | avg_batch_acc:0.967187 | avg_batch_loss:0.083223
# epoch:3 | step:200 | avg_batch_acc:0.950000 | avg_batch_loss:0.132427
# epoch:3 | step:220 | avg_batch_acc:0.962500 | avg_batch_loss:0.111382
# epoch:3 | step:240 | avg_batch_acc:0.960938 | avg_batch_loss:0.114950
# epoch:3 | step:260 | avg_batch_acc:0.962500 | avg_batch_loss:0.097187
# epoch:3 | step:280 | avg_batch_acc:0.956250 | avg_batch_loss:0.109201
# epoch:3 | step:300 | avg_batch_acc:0.965625 | avg_batch_loss:0.121620
# epoch:3 | step:320 | avg_batch_acc:0.964063 | avg_batch_loss:0.117067
# epoch:3 | step:340 | avg_batch_acc:0.953125 | avg_batch_loss:0.123880
# epoch:3 | step:360 | avg_batch_acc:0.964063 | avg_batch_loss:0.094367
# epoch:3 | step:380 | avg_batch_acc:0.964063 | avg_batch_loss:0.096683
# epoch:3 | step:400 | avg_batch_acc:0.960938 | avg_batch_loss:0.097600
# epoch:3 | step:420 | avg_batch_acc:0.951562 | avg_batch_loss:0.119191
# epoch:3 | step:440 | avg_batch_acc:0.968750 | avg_batch_loss:0.085899
# epoch:3 | step:460 | avg_batch_acc:0.959375 | avg_batch_loss:0.108823
# epoch:3 | step:480 | avg_batch_acc:0.950000 | avg_batch_loss:0.109962
# epoch:3 | step:500 | avg_batch_acc:0.968750 | avg_batch_loss:0.081499
# epoch:3 | step:520 | avg_batch_acc:0.965625 | avg_batch_loss:0.099665
# epoch:3 | step:540 | avg_batch_acc:0.964063 | avg_batch_loss:0.100052
# epoch:3 | step:560 | avg_batch_acc:0.954688 | avg_batch_loss:0.097250
# epoch:3 | step:580 | avg_batch_acc:0.956250 | avg_batch_loss:0.120116
# epoch:3 | step:600 | avg_batch_acc:0.951562 | avg_batch_loss:0.116200
# epoch:3 | step:620 | avg_batch_acc:0.951562 | avg_batch_loss:0.113724
# epoch:3 | step:640 | avg_batch_acc:0.959375 | avg_batch_loss:0.110184
# epoch:3 | step:660 | avg_batch_acc:0.976562 | avg_batch_loss:0.074985
# epoch:3 | step:680 | avg_batch_acc:0.950000 | avg_batch_loss:0.127701
# epoch:3 | step:700 | avg_batch_acc:0.970313 | avg_batch_loss:0.081067
# epoch:3 | step:720 | avg_batch_acc:0.945312 | avg_batch_loss:0.129656
# epoch:3 | step:740 | avg_batch_acc:0.953125 | avg_batch_loss:0.130679
# epoch:3 | step:760 | avg_batch_acc:0.946875 | avg_batch_loss:0.138416
# epoch:3 | step:780 | avg_batch_acc:0.954688 | avg_batch_loss:0.107265
# epoch:3 | step:800 | avg_batch_acc:0.960938 | avg_batch_loss:0.114089
# epoch:3 | step:820 | avg_batch_acc:0.959375 | avg_batch_loss:0.122826
# epoch:3 | step:840 | avg_batch_acc:0.951562 | avg_batch_loss:0.124068
# epoch:3 | step:860 | avg_batch_acc:0.964063 | avg_batch_loss:0.110358
# epoch:3 | step:880 | avg_batch_acc:0.957812 | avg_batch_loss:0.106559
# epoch:3 | step:900 | avg_batch_acc:0.962500 | avg_batch_loss:0.100514
# epoch:3 | step:920 | avg_batch_acc:0.959375 | avg_batch_loss:0.100405
# epoch:3 | step:940 | avg_batch_acc:0.950000 | avg_batch_loss:0.119064
# epoch:3 | step:960 | avg_batch_acc:0.956250 | avg_batch_loss:0.110160
# epoch:3 | step:980 | avg_batch_acc:0.957812 | avg_batch_loss:0.121307
# epoch:3 | step:1000 | avg_batch_acc:0.964063 | avg_batch_loss:0.127058
# epoch:3 | step:1020 | avg_batch_acc:0.962500 | avg_batch_loss:0.108663
# epoch:3 | step:1040 | avg_batch_acc:0.959375 | avg_batch_loss:0.119072
# epoch:3 | step:1060 | avg_batch_acc:0.948438 | avg_batch_loss:0.131864
# epoch:3 | step:1080 | avg_batch_acc:0.950000 | avg_batch_loss:0.123566
# epoch:3 | step:1100 | avg_batch_acc:0.962500 | avg_batch_loss:0.098072
# epoch:3 | step:1120 | avg_batch_acc:0.956250 | avg_batch_loss:0.109743
# epoch:3 | step:1140 | avg_batch_acc:0.948438 | avg_batch_loss:0.126938
# epoch:3 | step:1160 | avg_batch_acc:0.953125 | avg_batch_loss:0.119968
# epoch:3 | step:1180 | avg_batch_acc:0.948438 | avg_batch_loss:0.118666
# epoch:3 | step:1200 | avg_batch_acc:0.965625 | avg_batch_loss:0.081156
# epoch:3 | step:1220 | avg_batch_acc:0.971875 | avg_batch_loss:0.100308
# epoch:3 | step:1240 | avg_batch_acc:0.962500 | avg_batch_loss:0.098043
# epoch:3 | step:1260 | avg_batch_acc:0.973437 | avg_batch_loss:0.078929
# epoch:3 | step:1280 | avg_batch_acc:0.959375 | avg_batch_loss:0.101826
# epoch:3 | step:1300 | avg_batch_acc:0.968750 | avg_batch_loss:0.112972
# epoch:3 | step:1320 | avg_batch_acc:0.956250 | avg_batch_loss:0.108489
# epoch:3 | step:1340 | avg_batch_acc:0.964063 | avg_batch_loss:0.105149
# epoch:3 | step:1360 | avg_batch_acc:0.950000 | avg_batch_loss:0.107453
# epoch:3 | step:1380 | avg_batch_acc:0.962500 | avg_batch_loss:0.077433
# epoch:3 | step:1400 | avg_batch_acc:0.950000 | avg_batch_loss:0.111351
# epoch:3 | step:1420 | avg_batch_acc:0.957812 | avg_batch_loss:0.110039
# epoch:3 | step:1440 | avg_batch_acc:0.953125 | avg_batch_loss:0.134355
# epoch:3 | step:1460 | avg_batch_acc:0.964063 | avg_batch_loss:0.088977
# epoch:3 | step:1480 | avg_batch_acc:0.950000 | avg_batch_loss:0.125168
# epoch:3 | step:1500 | avg_batch_acc:0.957812 | avg_batch_loss:0.103637
# epoch:3 | step:1520 | avg_batch_acc:0.940625 | avg_batch_loss:0.134562
# epoch:3 | step:1540 | avg_batch_acc:0.975000 | avg_batch_loss:0.090263
# epoch:3 | step:1560 | avg_batch_acc:0.957812 | avg_batch_loss:0.090132
# epoch:3 | step:1580 | avg_batch_acc:0.970313 | avg_batch_loss:0.082779
# epoch:3 | step:1600 | avg_batch_acc:0.962500 | avg_batch_loss:0.098953
# epoch:3 | step:1620 | avg_batch_acc:0.968750 | avg_batch_loss:0.097547
# epoch:3 | step:1640 | avg_batch_acc:0.956250 | avg_batch_loss:0.091566
# epoch:3 | step:1660 | avg_batch_acc:0.964063 | avg_batch_loss:0.092214
# epoch:3 | step:1680 | avg_batch_acc:0.959375 | avg_batch_loss:0.094696
# epoch:3 | step:1700 | avg_batch_acc:0.956250 | avg_batch_loss:0.110019
# epoch:3 | step:1720 | avg_batch_acc:0.959375 | avg_batch_loss:0.096868
# epoch:3 | step:1740 | avg_batch_acc:0.967187 | avg_batch_loss:0.095357
# epoch:3 | step:1749 | avg_batch_acc:0.944444 | avg_batch_loss:0.117868
# epoch:3 | avg_train_loss:0.10728482369732643 | val_loss:0.2731459045261145 | val_accuracy:0.911625
# epoch:4 | step:20 | avg_batch_acc:0.979167 | avg_batch_loss:0.079736
# epoch:4 | step:40 | avg_batch_acc:0.964063 | avg_batch_loss:0.101357
# epoch:4 | step:60 | avg_batch_acc:0.981250 | avg_batch_loss:0.068284
# epoch:4 | step:80 | avg_batch_acc:0.962500 | avg_batch_loss:0.109025
# epoch:4 | step:100 | avg_batch_acc:0.975000 | avg_batch_loss:0.074141
# epoch:4 | step:120 | avg_batch_acc:0.968750 | avg_batch_loss:0.077816
# epoch:4 | step:140 | avg_batch_acc:0.975000 | avg_batch_loss:0.063886
# epoch:4 | step:160 | avg_batch_acc:0.976562 | avg_batch_loss:0.075969
# epoch:4 | step:180 | avg_batch_acc:0.970313 | avg_batch_loss:0.075919
# epoch:4 | step:200 | avg_batch_acc:0.973437 | avg_batch_loss:0.079678
# epoch:4 | step:220 | avg_batch_acc:0.981250 | avg_batch_loss:0.060239
# epoch:4 | step:240 | avg_batch_acc:0.971875 | avg_batch_loss:0.075791
# epoch:4 | step:260 | avg_batch_acc:0.979688 | avg_batch_loss:0.071562
# epoch:4 | step:280 | avg_batch_acc:0.967187 | avg_batch_loss:0.083427
# epoch:4 | step:300 | avg_batch_acc:0.965625 | avg_batch_loss:0.093563
# epoch:4 | step:320 | avg_batch_acc:0.965625 | avg_batch_loss:0.085034
# epoch:4 | step:340 | avg_batch_acc:0.985938 | avg_batch_loss:0.053380
# epoch:4 | step:360 | avg_batch_acc:0.973437 | avg_batch_loss:0.072921
# epoch:4 | step:380 | avg_batch_acc:0.967187 | avg_batch_loss:0.096319
# epoch:4 | step:400 | avg_batch_acc:0.970313 | avg_batch_loss:0.074195
# epoch:4 | step:420 | avg_batch_acc:0.970313 | avg_batch_loss:0.082482
# epoch:4 | step:440 | avg_batch_acc:0.960938 | avg_batch_loss:0.106334
# epoch:4 | step:460 | avg_batch_acc:0.967187 | avg_batch_loss:0.091524
# epoch:4 | step:480 | avg_batch_acc:0.968750 | avg_batch_loss:0.088614
# epoch:4 | step:500 | avg_batch_acc:0.962500 | avg_batch_loss:0.096891
# epoch:4 | step:520 | avg_batch_acc:0.971875 | avg_batch_loss:0.064829
# epoch:4 | step:540 | avg_batch_acc:0.984375 | avg_batch_loss:0.054529
# epoch:4 | step:560 | avg_batch_acc:0.968750 | avg_batch_loss:0.074226
# epoch:4 | step:580 | avg_batch_acc:0.975000 | avg_batch_loss:0.081506
# epoch:4 | step:600 | avg_batch_acc:0.964063 | avg_batch_loss:0.092578
# epoch:4 | step:620 | avg_batch_acc:0.971875 | avg_batch_loss:0.082953
# epoch:4 | step:640 | avg_batch_acc:0.979688 | avg_batch_loss:0.054129
# epoch:4 | step:660 | avg_batch_acc:0.948438 | avg_batch_loss:0.126060
# epoch:4 | step:680 | avg_batch_acc:0.965625 | avg_batch_loss:0.089022
# epoch:4 | step:700 | avg_batch_acc:0.970313 | avg_batch_loss:0.080569
# epoch:4 | step:720 | avg_batch_acc:0.962500 | avg_batch_loss:0.101659
# epoch:4 | step:740 | avg_batch_acc:0.962500 | avg_batch_loss:0.104004
# epoch:4 | step:760 | avg_batch_acc:0.962500 | avg_batch_loss:0.091751
# epoch:4 | step:780 | avg_batch_acc:0.960938 | avg_batch_loss:0.083463
# epoch:4 | step:800 | avg_batch_acc:0.982812 | avg_batch_loss:0.058949
# epoch:4 | step:820 | avg_batch_acc:0.957812 | avg_batch_loss:0.104374
# epoch:4 | step:840 | avg_batch_acc:0.960938 | avg_batch_loss:0.098097
# epoch:4 | step:860 | avg_batch_acc:0.971875 | avg_batch_loss:0.072696
# epoch:4 | step:880 | avg_batch_acc:0.975000 | avg_batch_loss:0.093371
# epoch:4 | step:900 | avg_batch_acc:0.964063 | avg_batch_loss:0.085541
# epoch:4 | step:920 | avg_batch_acc:0.975000 | avg_batch_loss:0.072695
# epoch:4 | step:940 | avg_batch_acc:0.948438 | avg_batch_loss:0.117405
# epoch:4 | step:960 | avg_batch_acc:0.973437 | avg_batch_loss:0.072269
# epoch:4 | step:980 | avg_batch_acc:0.975000 | avg_batch_loss:0.062155
# epoch:4 | step:1000 | avg_batch_acc:0.964063 | avg_batch_loss:0.090121
# epoch:4 | step:1020 | avg_batch_acc:0.970313 | avg_batch_loss:0.092223
# epoch:4 | step:1040 | avg_batch_acc:0.960938 | avg_batch_loss:0.087875
# epoch:4 | step:1060 | avg_batch_acc:0.957812 | avg_batch_loss:0.096572
# epoch:4 | step:1080 | avg_batch_acc:0.970313 | avg_batch_loss:0.073056
# epoch:4 | step:1100 | avg_batch_acc:0.965625 | avg_batch_loss:0.100993
# epoch:4 | step:1120 | avg_batch_acc:0.968750 | avg_batch_loss:0.082028
# epoch:4 | step:1140 | avg_batch_acc:0.967187 | avg_batch_loss:0.082090
# epoch:4 | step:1160 | avg_batch_acc:0.967187 | avg_batch_loss:0.087964
# epoch:4 | step:1180 | avg_batch_acc:0.975000 | avg_batch_loss:0.085814
# epoch:4 | step:1200 | avg_batch_acc:0.970313 | avg_batch_loss:0.095763
# epoch:4 | step:1220 | avg_batch_acc:0.968750 | avg_batch_loss:0.079101
# epoch:4 | step:1240 | avg_batch_acc:0.971875 | avg_batch_loss:0.081454
# epoch:4 | step:1260 | avg_batch_acc:0.976562 | avg_batch_loss:0.080753
# epoch:4 | step:1280 | avg_batch_acc:0.979688 | avg_batch_loss:0.055493
# epoch:4 | step:1300 | avg_batch_acc:0.957812 | avg_batch_loss:0.113382
# epoch:4 | step:1320 | avg_batch_acc:0.970313 | avg_batch_loss:0.074319
# epoch:4 | step:1340 | avg_batch_acc:0.973437 | avg_batch_loss:0.081948
# epoch:4 | step:1360 | avg_batch_acc:0.973437 | avg_batch_loss:0.078867
# epoch:4 | step:1380 | avg_batch_acc:0.970313 | avg_batch_loss:0.098742
# epoch:4 | step:1400 | avg_batch_acc:0.967187 | avg_batch_loss:0.108639
# epoch:4 | step:1420 | avg_batch_acc:0.965625 | avg_batch_loss:0.089514
# epoch:4 | step:1440 | avg_batch_acc:0.960938 | avg_batch_loss:0.091516
# epoch:4 | step:1460 | avg_batch_acc:0.979688 | avg_batch_loss:0.052795
# epoch:4 | step:1480 | avg_batch_acc:0.971875 | avg_batch_loss:0.075584
# epoch:4 | step:1500 | avg_batch_acc:0.971875 | avg_batch_loss:0.067219
# epoch:4 | step:1520 | avg_batch_acc:0.973437 | avg_batch_loss:0.090342
# epoch:4 | step:1540 | avg_batch_acc:0.965625 | avg_batch_loss:0.108716
# epoch:4 | step:1560 | avg_batch_acc:0.975000 | avg_batch_loss:0.065382
# epoch:4 | step:1580 | avg_batch_acc:0.971875 | avg_batch_loss:0.077547
# epoch:4 | step:1600 | avg_batch_acc:0.965625 | avg_batch_loss:0.089178
# epoch:4 | step:1620 | avg_batch_acc:0.962500 | avg_batch_loss:0.095782
# epoch:4 | step:1640 | avg_batch_acc:0.970313 | avg_batch_loss:0.090051
# epoch:4 | step:1660 | avg_batch_acc:0.964063 | avg_batch_loss:0.093063
# epoch:4 | step:1680 | avg_batch_acc:0.965625 | avg_batch_loss:0.081561
# epoch:4 | step:1700 | avg_batch_acc:0.965625 | avg_batch_loss:0.090586
# epoch:4 | step:1720 | avg_batch_acc:0.973437 | avg_batch_loss:0.091116
# epoch:4 | step:1740 | avg_batch_acc:0.953125 | avg_batch_loss:0.105283
# epoch:4 | step:1749 | avg_batch_acc:0.951389 | avg_batch_loss:0.091176
# epoch:4 | avg_train_loss:0.0843927411322615 | val_loss:0.2899354337193072 | val_accuracy:0.912375
# 保存训练完成的model...

# %%
print('开始加载训练完成的model...')
model.load_state_dict(torch.load('bert_cla_db2.ckpt'))
# Out:
# 开始加载训练完成的model...
# <All keys matched successfully>

# %%
print('开始测试...')
model.eval()
test_result = []
for data in test_data:
    b_input_ids, b_attn_mask, b_labels = tuple(t.to(device) for t in data)
    b_input = b_input_ids.unsqueeze(0)
    
    with torch.no_grad():
        outputs = model(b_input)
        pre = outputs.logits.argmax(dim=1)
        test_result.append([b_labels.item(), pre.item(), tokenizer.convert_ids_to_tokens(b_input_ids)])

# 写入csv文件
df = pd.DataFrame(test_result)
df.to_csv('test_result_db2.csv',index=False, header=['id', 'label','text'])
# Out:
# 开始测试...

# %%
import pandas as pd
df = pd.read_csv('test_result_db2.csv')
df[df.id!=df.label]
# Out:
#        id  label                                               text
# 3       2      0  ['[CLS]', '我', '申', '请', '了', '大', '同', '飞', '...
# 7       1      0  ['[CLS]', '你', '好', '我', '想', '开', '通', '家', '...
# 8       0      2  ['[CLS]', '没', '答', '应', '[UNK]', '[SEP]', '[P...
# 15      1      0  ['[CLS]', '免', '费', '领', '1g', '[SEP]', '[PAD]...
# 32      2      0  ['[CLS]', '不', '开', '了', '可', '以', '吧', '[SEP]...
# ...    ..    ...                                                ...
# 15966   2      0  ['[CLS]', '操', '你', '可', '以', '吗', '[SEP]', '[...
# 15980   2      0  ['[CLS]', 'p', '想', '过', '胖', '了', 'n', '红', '...
# 15983   0      2  ['[CLS]', '每', '月', '用', '不', '完', '的', '套', '...
# 15987   1      0  ['[CLS]', 'so', '##ea', '##sy', '##y', '[SEP]'...
# 15996   1      2  ['[CLS]', '我', '到', '了', '亲', '爱', '的', '第', '...
#
# [2213 rows x 3 columns]

# %%
len(df[df.id==df.label])/len(df)
# Out:
# 0.8616875
